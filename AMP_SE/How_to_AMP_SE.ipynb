# %% [markdown]
# # $\color{Darkred}{\text{How-to AMP & SE}}$

# %% [markdown]
# The notebook is a demo for the implementation of the results regarding AMP and its State Evolution for the Subspace Clustering problem. It is divided in three sections:
#
# * **Import:** Import the .py script which we implemented along with the basic Python packages.
# * **Analysis of the MSE:** Analysis of the MSE for the Subspace Clustering problem for AMP and its State Evolution for a fixed sparsity level $\rho$ and aspect ratio $\alpha$.
# * **Threshold:** Computation of the different thresholds highlighting the evolution of the different reconstruction phases.

# %% [markdown]
# ### $\color{Darkred}{\text{Import}}$

# %%
import numpy as np
import matplotlib.pyplot as plt
from SE_AMP_functions import *

# %% [markdown]
# ### $\color{Darkred}{\text{Analysis of the MSE}}$

# %% [markdown]
# We analyze the Mean Squared Error achieved by AMP and its associated State Evolution for the Subspace clustering problem. The SE equations are valid in the infinite size limit $n,d \to \infty$. Despite this, we observe from the plot that the AMP performance, on a factor graph with $(n,d) = (2000,1000)$, agrees with its SE equations.

# %% [markdown]
# ##### $\color{Purple}{\text{State Evolution}}$

# %%
coefs = np.linspace(0.1,2.5,500) ; alpha = 2 ; damping = 0 ; tol = 10e-12 ; rho = 0.5 
se_inf , se_uninf = [] , []
for coef in coefs:
    # Rescale the snr according to the sparsity level
    snr = coef/(rho*np.sqrt(alpha))
    # Informed
    init_u , init_v = 1,rho   
    iteration = iterate_UV(init_u,init_v, tol=tol, max_steps = 1000,
                snr=snr,  rho=rho,alpha=alpha,damping=damping )
    # Uninformed
    init_u_un , init_v_un = 10e-4,10e-4 
    iteration_un = iterate_UV(init_u_un,init_v_un, tol=tol, max_steps = 1000,
                                                snr=snr, rho=rho,alpha=alpha,damping=damping)
    se_inf.append(iteration[2]) ; se_uninf.append(iteration_un[2])
# Out:
# SE iteration with snr=0.1414213562373095 and rho=0.5
# At time 0 we have deltau = 0.9337877262883264 and deltav=0.49536093166017064 and Mu = 0.0662122737116736 and Mv = 0.004639068339829354
# At time 6 SE converged with well defined overlap = 6.555713894501317e-12
# SE iteration with snr=0.1414213562373095 and rho=0.5
# At time 0 we have deltau = 0.0008585986390793532 and deltav=0.000990001613815854 and Mu = 0.0001414013609206469 and Mv = 9.998386184145971e-06
# At time 5 SE converged with well defined overlap = 1.4139910831503539e-12
# SE iteration with snr=0.14822318499421416 and rho=0.5
# At time 0 we have deltau = 0.930807356427074 and deltav=0.49492331290596053 and Mu = 0.06919264357292604 and Mv = 0.005076687094039463
# At time 7 SE converged with well defined overlap = 1.2026309464186575e-13
# SE iteration with snr=0.14822318499421416 and rho=0.5
# At time 0 we have deltau = 0.0008517987797233422 and deltav=0.0009890168128134343 and Mu = 0.00014820122027665785 and Mv = 1.0983187186565818e-05
# At time 5 SE converged with well defined overlap = 2.158007942563085e-12
# SE iteration with snr=0.15502501375111882 and rho=0.5
# At time 0 we have deltau = 0.9278438789630951 and deltav=0.4944678770066273 and Mu = 0.07215612103690494 and Mv = 0.005532122993372699
# At time 7 SE converged with well defined overlap = 2.1464950812953057e-13
# SE iteration with snr=0.15502501375111882 and rho=0.5
# At time 0 we have deltau = 0.000844999012828556 and deltav=0.000987985773595959 and Mu = 0.00015500098717144406 and Mv = 1.2014226404041027e-05
# At time 5 SE converged with well defined overlap = 3.231616394477595e-12
# SE iteration with snr=0.16182684250802348 and rho=0.5
# At time 0 we have deltau = 0.9248970862307119 and deltav=0.49399486858728014 and Mu = 0.07510291376928817 and Mv = 0.006005131412719828
# At time 7 SE converged with well defined overlap = 3.736249774072893e-13
# SE iteration with snr=0.16182684250802348 and rho=0.5
# At time 0 we have deltau = 0.0008381993383587206 and deltav=0.0009869084976758204 and Mu = 0.0001618006616412795 and Mv = 1.3091502324179665e-05
# At time 5 SE converged with well defined overlap = 4.756142015586475e-12
# SE iteration with snr=0.16862867126492817 and rho=0.5
# At time 0 we have deltau = 0.9219667754110826 and deltav=0.4935045315122908 and Mu = 0.07803322458891736 and Mv = 0.006495468487709188
# At time 7 SE converged with well defined overlap = 6.355444144073669e-13
# SE iteration with snr=0.16862867126492817 and rho=0.5
# At time 0 we have deltau = 0.0008313997563755756 and deltav=0.0009857849865988026 and Mu = 0.00016860024362442443 and Mv = 1.421501340119738e-05
# At time 5 SE converged with well defined overlap = 6.889353217364296e-12
# SE iteration with snr=0.17543050002183283 and rho=0.5
# At time 0 we have deltau = 0.9190527483561484 and deltav=0.4929971087847973 and Mu = 0.08094725164385169 and Mv = 0.007002891215202698
# At time 7 SE converged with well defined overlap = 1.058401643308079e-12
# SE iteration with snr=0.17543050002183283 and rho=0.5
# At time 0 we have deltau = 0.0008246002668442322 and deltav=0.0009846152419286732 and Mu = 0.00017539973315576775 and Mv = 1.5384758071326785e-05
# At time 6 SE converged with well defined overlap = 1.5132778479391302e-13
# SE iteration with snr=0.1822323287787375 and rho=0.5
# At time 0 we have deltau = 0.9161548114214254 and deltav=0.49247284244934647 and Mu = 0.08384518857857459 and Mv = 0.007527157550653502
# At time 7 SE converged with well defined overlap = 1.7284177071093077e-12
# SE iteration with snr=0.1822323287787375 and rho=0.5
# At time 0 we have deltau = 0.0008178008697615495 and deltav=0.0009833992652572322 and Mu = 0.00018219913023845053 and Mv = 1.6600734742767872e-05
# At time 6 SE converged with well defined overlap = 2.2995245398574797e-13
# SE iteration with snr=0.18903415753564212 and rho=0.5
# At time 0 we have deltau = 0.9132727753070732 and deltav=0.4919319734980185 and Mu = 0.08672722469292685 and Mv = 0.008068026501981513
# At time 7 SE converged with well defined overlap = 2.7718040596029856e-12
# SE iteration with snr=0.18903415753564212 and rho=0.5
# At time 0 we have deltau = 0.0008110015651243862 and deltav=0.0009821370582018473 and Mu = 0.0001889984348756138 and Mv = 1.7862941798152692e-05
# At time 6 SE converged with well defined overlap = 3.441099849414821e-13
# SE iteration with snr=0.19583598629254684 and rho=0.5
# At time 0 we have deltau = 0.9104064549067048 and deltav=0.4913747417803431 and Mu = 0.08959354509329515 and Mv = 0.008625258219656859
# At time 7 SE converged with well defined overlap = 4.370685020853251e-12
# SE iteration with snr=0.19583598629254684 and rho=0.5
# At time 0 we have deltau = 0.0008042023529296009 and deltav=0.0009808286224054505 and Mu = 0.00019579764707039913 and Mv = 1.9171377594549547e-05
# At time 6 SE converged with well defined overlap = 5.076534254791167e-13
# SE iteration with snr=0.2026378150494515 and rho=0.5
# At time 0 we have deltau = 0.9075556691634579 and deltav=0.4908013859172861 and Mu = 0.0924443308365421 and Mv = 0.009198614082713904
# At time 7 SE converged with well defined overlap = 6.78435533702597e-12
# SE iteration with snr=0.2026378150494515 and rho=0.5
# At time 0 we have deltau = 0.0007974032331740531 and deltav=0.0009794739595365331 and Mu = 0.00020259676682594696 and Mv = 2.0526040463466914e-05
# At time 6 SE converged with well defined overlap = 7.390450296006083e-13
# SE iteration with snr=0.20943964380635616 and rho=0.5
# At time 0 we have deltau = 0.9047202409328728 and deltav=0.49021214321954876 and Mu = 0.09527975906712717 and Mv = 0.009787856780451245
# At time 8 SE converged with well defined overlap = 2.276032738537047e-13
# SE iteration with snr=0.20943964380635616 and rho=0.5
# At time 0 we have deltau = 0.0007906042058546026 and deltav=0.0009780730712891422 and Mu = 0.0002093957941453975 and Mv = 2.1926928710857847e-05
# At time 6 SE converged with well defined overlap = 1.0626465718480357e-12
# SE iteration with snr=0.21624147256326084 and rho=0.5
# At time 0 we have deltau = 0.9018999968521672 and deltav=0.48960724961039526 and Mu = 0.09810000314783289 and Mv = 0.01039275038960473
# At time 8 SE converged with well defined overlap = 3.6605697401459083e-13
# SE iteration with snr=0.21624147256326084 and rho=0.5
# At time 0 we have deltau = 0.0007838052709681098 and deltav=0.0009766259593828757 and Mu = 0.0002161947290318903 and Mv = 2.337404061712425e-05
# At time 6 SE converged with well defined overlap = 1.5103077949004705e-12
# SE iteration with snr=0.2230433013201655 and rho=0.5
# At time 0 we have deltau = 0.8990947672155196 and deltav=0.4889869395531877 and Mu = 0.10090523278448033 and Mv = 0.01101306044681228
# At time 8 SE converged with well defined overlap = 5.800385798845108e-13
# SE iteration with snr=0.2230433013201655 and rho=0.5
# At time 0 we have deltau = 0.0007770064285114339 and deltav=0.0009751326255628785 and Mu = 0.00022299357148856608 and Mv = 2.48673744371215e-05
# At time 6 SE converged with well defined overlap = 2.1233083386510836e-12
# SE iteration with snr=0.22984513007707016 and rho=0.5
# At time 0 we have deltau = 0.8963043858550106 and deltav=0.48835144598377994 and Mu = 0.10369561414498946 and Mv = 0.011648554016220058
# At time 8 SE converged with well defined overlap = 9.063385603878661e-13
# SE iteration with snr=0.22984513007707016 and rho=0.5
# At time 0 we have deltau = 0.0007702076784814364 and deltav=0.0009735930715998374 and Mu = 0.00022979232151856368 and Mv = 2.6406928400162616e-05
# At time 6 SE converged with well defined overlap = 2.9547164334346045e-12
# SE iteration with snr=0.2366469588339748 and rho=0.5
# At time 0 we have deltau = 0.893528690026887 and deltav=0.4877010002478904 and Mu = 0.10647130997311306 and Mv = 0.012298999752109551
# At time 8 SE converged with well defined overlap = 1.3976643034352706e-12
# SE iteration with snr=0.2366469588339748 and rho=0.5
# At time 0 we have deltau = 0.0007634090208749771 and deltav=0.0009720072992899768 and Mu = 0.0002365909791250229 and Mv = 2.799270071002323e-05
# At time 6 SE converged with well defined overlap = 4.072236399688996e-12
# SE iteration with snr=0.24344878759087946 and rho=0.5
# At time 0 we have deltau = 0.8907675203028489 and deltav=0.487035832043545 and Mu = 0.10923247969715107 and Mv = 0.012964167956455013
# At time 8 SE converged with well defined overlap = 2.1287149375171274e-12
# SE iteration with snr=0.24344878759087946 and rho=0.5
# At time 0 we have deltau = 0.0007566104556889164 and deltav=0.0009703753104550539 and Mu = 0.00024338954431108362 and Mv = 2.9624689544946115e-05
# At time 6 SE converged with well defined overlap = 5.561620544551491e-12
# SE iteration with snr=0.2502506163477841 and rho=0.5
# At time 0 we have deltau = 0.8880207204617367 and deltav=0.4863561693681359 and Mu = 0.11197927953826321 and Mv = 0.013643830631864072
# At time 8 SE converged with well defined overlap = 3.204283952832295e-12
# SE iteration with snr=0.2502506163477841 and rho=0.5
# At time 0 we have deltau = 0.0007498119829201153 and deltav=0.0009686971069423541 and Mu = 0.00025018801707988475 and Mv = 3.1302893057645914e-05
# At time 6 SE converged with well defined overlap = 7.530772097832601e-12
# SE iteration with snr=0.2570524451046888 and rho=0.5
# At time 0 we have deltau = 0.8852881374073065 and deltav=0.48566223847320167 and Mu = 0.11471186259269352 and Mv = 0.014337761526798354
# At time 8 SE converged with well defined overlap = 4.769974768636315e-12
# SE iteration with snr=0.2570524451046888 and rho=0.5
# At time 0 we have deltau = 0.0007430136025654362 and deltav=0.0009669726906246861 and Mu = 0.0002569863974345638 and Mv = 3.302730937531389e-05
# At time 7 SE converged with well defined overlap = 3.341650507571064e-13
# SE iteration with snr=0.2638542738615935 and rho=0.5
# At time 0 we have deltau = 0.8825696210515407 and deltav=0.48495426381986 and Mu = 0.11743037894845934 and Mv = 0.015045736180139987
# At time 8 SE converged with well defined overlap = 7.02625853937646e-12
# SE iteration with snr=0.2638542738615935 and rho=0.5
# At time 0 we have deltau = 0.0007362153146217395 and deltav=0.0009652020634003766 and Mu = 0.00026378468537826053 and Mv = 3.479793659962339e-05
# At time 7 SE converged with well defined overlap = 4.69253185264222e-13
# SE iteration with snr=0.27065610261849815 and rho=0.5
# At time 0 we have deltau = 0.8798650242228322 and deltav=0.4842324680416821 and Mu = 0.12013497577716784 and Mv = 0.015767531958317926
# At time 9 SE converged with well defined overlap = 3.753128640222307e-13
# SE iteration with snr=0.27065610261849815 and rho=0.5
# At time 0 we have deltau = 0.0007294171190858873 and deltav=0.0009633852271932657 and Mu = 0.0002705828809141127 and Mv = 3.66147728067343e-05
# At time 7 SE converged with well defined overlap = 6.532812925307399e-13
# SE iteration with snr=0.2774579313754028 and rho=0.5
# At time 0 we have deltau = 0.877174202600674 and deltav=0.48349707191562874 and Mu = 0.12282579739932596 and Mv = 0.016502928084371232
# At time 9 SE converged with well defined overlap = 5.697504186490407e-13
# SE iteration with snr=0.2774579313754028 and rho=0.5
# At time 0 we have deltau = 0.0007226190159547413 and deltav=0.0009615221839527015 and Mu = 0.00027738098404525867 and Mv = 3.847781604729853e-05
# At time 7 SE converged with well defined overlap = 9.020411110700937e-13
# SE iteration with snr=0.28425976013230747 and rho=0.5
# At time 0 we have deltau = 0.8744970146141314 and deltav=0.48274829433310834 and Mu = 0.12550298538586854 and Mv = 0.017251705666891638
# At time 9 SE converged with well defined overlap = 8.560977977561835e-13
# SE iteration with snr=0.28425976013230747 and rho=0.5
# At time 0 we have deltau = 0.0007158210052251635 and deltav=0.0009596129356535348 and Mu = 0.00028417899477483656 and Mv = 4.038706434646519e-05
# At time 7 SE converged with well defined overlap = 1.2358288919571242e-12
# SE iteration with snr=0.29106158888921213 and rho=0.5
# At time 0 we have deltau = 0.8718333213656928 and deltav=0.4819863522786694 and Mu = 0.12816667863430722 and Mv = 0.018013647721330565
# At time 9 SE converged with well defined overlap = 1.273851665864439e-12
# SE iteration with snr=0.29106158888921213 and rho=0.5
# At time 0 we have deltau = 0.0007090230868940157 and deltav=0.0009576574842961142 and Mu = 0.0002909769131059844 and Mv = 4.234251570388585e-05
# At time 7 SE converged with well defined overlap = 1.6805707031995075e-12
# SE iteration with snr=0.2978634176461168 and rho=0.5
# At time 0 we have deltau = 0.8691829865539514 and deltav=0.4812114608129944 and Mu = 0.13081701344604854 and Mv = 0.018788539187005602
# At time 9 SE converged with well defined overlap = 1.877873319943029e-12
# SE iteration with snr=0.2978634176461168 and rho=0.5
# At time 0 we have deltau = 0.0007022252609581611 and deltav=0.0009556558319062803 and Mu = 0.0002977747390418389 and Mv = 4.434416809371975e-05
# At time 7 SE converged with well defined overlap = 2.269191065582601e-12
# SE iteration with snr=0.30466524640302145 and rho=0.5
# At time 0 we have deltau = 0.8665458763993406 and deltav=0.48042383306059333 and Mu = 0.1334541236006594 and Mv = 0.019576166939406673
# At time 9 SE converged with well defined overlap = 2.743769569015543e-12
# SE iteration with snr=0.30466524640302145 and rho=0.5
# At time 0 we have deltau = 0.0006954275274144626 and deltav=0.0009536079805353604 and Mu = 0.0003045724725855374 and Mv = 4.639201946463964e-05
# At time 7 SE converged with well defined overlap = 3.04326978363016e-12
# SE iteration with snr=0.3114670751599261 and rho=0.5
# At time 0 we have deltau = 0.8639218595727667 and deltav=0.4796236802020457 and Mu = 0.13607814042723335 and Mv = 0.020376319797954293
# At time 9 SE converged with well defined overlap = 3.974960106842836e-12
# SE iteration with snr=0.3114670751599261 and rho=0.5
# At time 0 we have deltau = 0.0006886298862597833 and deltav=0.0009515139322601629 and Mu = 0.0003113701137402168 and Mv = 4.84860677398371e-05
# At time 7 SE converged with well defined overlap = 4.055038744664666e-12
# SE iteration with snr=0.3182689039168308 and rho=0.5
# At time 0 we have deltau = 0.8613108071269976 and deltav=0.47881121147061967 and Mu = 0.13868919287300244 and Mv = 0.02118878852938036
# At time 9 SE converged with well defined overlap = 5.711899586319844e-12
# SE iteration with snr=0.3182689039168308 and rho=0.5
# At time 0 we have deltau = 0.0006818323374909852 and deltav=0.0009493736891829715 and Mu = 0.00031816766250901483 and Mv = 5.062631081702848e-05
# At time 7 SE converged with well defined overlap = 5.369778238283198e-12
# SE iteration with snr=0.32507073267373543 and rho=0.5
# At time 0 we have deltau = 0.8587125924306699 and deltav=0.4779866341530823 and Mu = 0.14128740756933014 and Mv = 0.022013365846917692
# At time 9 SE converged with well defined overlap = 8.144037415758464e-12
# SE iteration with snr=0.32507073267373543 and rho=0.5
# At time 0 we have deltau = 0.0006750348811049331 and deltav=0.0009471872534315399 and Mu = 0.000324965118895067 and Mv = 5.281274656846013e-05
# At time 7 SE converged with well defined overlap = 7.068681075605427e-12
# SE iteration with snr=0.3318725614306401 and rho=0.5
# At time 0 we have deltau = 0.8561270911047867 and deltav=0.47715015359450075 and Mu = 0.14387290889521331 and Mv = 0.022849846405499245
# At time 10 SE converged with well defined overlap = 6.346927774751568e-13
# SE iteration with snr=0.3318725614306401 and rho=0.5
# At time 0 we have deltau = 0.0006682375170984898 and deltav=0.0009449546271590852 and Mu = 0.00033176248290151016 and Mv = 5.504537284091483e-05
# At time 8 SE converged with well defined overlap = 5.095204836120109e-13
# SE iteration with snr=0.33867439018754475 and rho=0.5
# At time 0 we have deltau = 0.8535541809615877 and deltav=0.4763019732068197 and Mu = 0.14644581903841228 and Mv = 0.023698026793180307
# At time 10 SE converged with well defined overlap = 9.287045124266017e-13
# SE iteration with snr=0.33867439018754475 and rho=0.5
# At time 0 we have deltau = 0.0006614402454685187 and deltav=0.0009426758125442825 and Mu = 0.0003385597545314813 and Mv = 5.732418745571744e-05
# At time 8 SE converged with well defined overlap = 6.907502956902875e-13
# SE iteration with snr=0.34547621894444946 and rho=0.5
# At time 0 we have deltau = 0.850993741945677 and deltav=0.4754422944809908 and Mu = 0.149006258054323 and Mv = 0.02455770551900921
# At time 10 SE converged with well defined overlap = 1.348485140540372e-12
# SE iteration with snr=0.34547621894444946 and rho=0.5
# At time 0 we have deltau = 0.0006546430662118857 and deltav=0.0009403508117912595 and Mu = 0.00034535693378811433 and Mv = 5.96491882087405e-05
# At time 8 SE converged with well defined overlap = 9.307912282702836e-13
# SE iteration with snr=0.3522780477013541 and rho=0.5
# At time 0 we have deltau = 0.8484456560773035 and deltav=0.4745713170024194 and Mu = 0.1515543439226965 and Mv = 0.02542868299758058
# At time 10 SE converged with well defined overlap = 1.9435645635524634e-12
# SE iteration with snr=0.3522780477013541 and rho=0.5
# At time 0 we have deltau = 0.0006478459793254539 and deltav=0.0009379796271295888 and Mu = 0.0003521540206745461 and Mv = 6.20203728704112e-05
# At time 8 SE converged with well defined overlap = 1.2469749873647181e-12
# SE iteration with snr=0.3590798764582588 and rho=0.5
# At time 0 we have deltau = 0.845909807397693 and deltav=0.47368923846948585 and Mu = 0.154090192602307 and Mv = 0.026310761530514135
# At time 10 SE converged with well defined overlap = 2.7813657807143853e-12
# SE iteration with snr=0.3590798764582588 and rho=0.5
# At time 0 we have deltau = 0.0006410489848060883 and deltav=0.0009355622608142831 and Mu = 0.0003589510151939117 and Mv = 6.443773918571696e-05
# At time 8 SE converged with well defined overlap = 1.661246454224337e-12
# SE iteration with snr=0.36588170521516344 and rho=0.5
# At time 0 we have deltau = 0.8433860819163379 and deltav=0.4727962547148923 and Mu = 0.15661391808366215 and Mv = 0.0272037452851077
# At time 10 SE converged with well defined overlap = 3.953099990957944e-12
# SE iteration with snr=0.36588170521516344 and rho=0.5
# At time 0 we have deltau = 0.0006342520826506525 and deltav=0.0009330987151257881 and Mu = 0.0003657479173493475 and Mv = 6.690128487421191e-05
# At time 8 SE converged with well defined overlap = 2.201265482312152e-12
# SE iteration with snr=0.3726835339720681 and rho=0.5
# At time 0 we have deltau = 0.840874367560155 and deltav=0.471892559729582 and Mu = 0.159125632439845 and Mv = 0.02810744027041799
# At time 10 SE converged with well defined overlap = 5.581473951873113e-12
# SE iteration with snr=0.3726835339720681 and rho=0.5
# At time 0 we have deltau = 0.0006274552728560131 and deltav=0.0009305889923699772 and Mu = 0.0003725447271439869 and Mv = 6.941100763002288e-05
# At time 8 SE converged with well defined overlap = 2.9017429687633423e-12
# SE iteration with snr=0.3794853627289728 and rho=0.5
# At time 0 we have deltau = 0.8383745541244274 and deltav=0.4709783456889739 and Mu = 0.16162544587557257 and Mv = 0.029021654311026084
# At time 10 SE converged with well defined overlap = 7.830568977821188e-12
# SE iteration with snr=0.3794853627289728 and rho=0.5
# At time 0 we have deltau = 0.0006206585554190332 and deltav=0.0009280330948781432 and Mu = 0.0003793414445809668 and Mv = 7.19669051218568e-05
# At time 8 SE converged with well defined overlap = 3.806055122711683e-12
# SE iteration with snr=0.3862871914858774 and rho=0.5
# At time 0 we have deltau = 0.8358865332254507 and deltav=0.47005380298125476 and Mu = 0.1641134667745493 and Mv = 0.02994619701874523
# At time 11 SE converged with well defined overlap = 8.146294031142513e-13
# SE iteration with snr=0.3862871914858774 and rho=0.5
# At time 0 we have deltau = 0.0006138619303365804 and deltav=0.0009254310250069943 and Mu = 0.0003861380696634197 and Mv = 7.456897499300572e-05
# At time 8 SE converged with well defined overlap = 4.968187024314856e-12
# SE iteration with snr=0.39308902024278214 and rho=0.5
# At time 0 we have deltau = 0.8334101982548078 and deltav=0.4691191202374706 and Mu = 0.1665898017451922 and Mv = 0.030880879762529425
# At time 11 SE converged with well defined overlap = 1.1692824685214036e-12
# SE iteration with snr=0.39308902024278214 and rho=0.5
# At time 0 we have deltau = 0.0006070653976055192 and deltav=0.0009227827851386451 and Mu = 0.00039293460239448087 and Mv = 7.721721486135493e-05
# At time 8 SE converged with well defined overlap = 6.455056899041592e-12
# SE iteration with snr=0.3998908489996867 and rho=0.5
# At time 0 we have deltau = 0.8309454443352027 and deltav=0.4681744843631611 and Mu = 0.16905455566479732 and Mv = 0.031825515636838914
# At time 11 SE converged with well defined overlap = 1.6677432988815617e-12
# SE iteration with snr=0.3998908489996867 and rho=0.5
# At time 0 we have deltau = 0.0006002689572227147 and deltav=0.000920088377680611 and Mu = 0.0003997310427772853 and Mv = 7.991162231938903e-05
# At time 8 SE converged with well defined overlap = 8.349325334851512e-12
# SE iteration with snr=0.40669267775659146 and rho=0.5
# At time 0 we have deltau = 0.8284921682777829 and deltav=0.46722008057128367 and Mu = 0.1715078317222171 and Mv = 0.032779919428716324
# At time 11 SE converged with well defined overlap = 2.364183659848842e-12
# SE iteration with snr=0.40669267775659146 and rho=0.5
# At time 0 we have deltau = 0.0005934726091850352 and deltav=0.0009173478050658019 and Mu = 0.0004065273908149648 and Mv = 8.26521949341981e-05
# At time 9 SE converged with well defined overlap = 8.892457617686686e-13
# SE iteration with snr=0.4134945065134961 and rho=0.5
# At time 0 we have deltau = 0.8260502685408907 and deltav=0.4662560924161781 and Mu = 0.17394973145910927 and Mv = 0.03374390758382188
# At time 11 SE converged with well defined overlap = 3.331675517622764e-12
# SE iteration with snr=0.4134945065134961 and rho=0.5
# At time 0 we have deltau = 0.0005866763534893456 and deltav=0.000914561069752514 and Mu = 0.0004133236465106544 and Mv = 8.543893024748594e-05
# At time 9 SE converged with well defined overlap = 1.1788885496721788e-12
# SE iteration with snr=0.4202963352704008 and rho=0.5
# At time 0 we have deltau = 0.8236196451901779 and deltav=0.4652827018283278 and Mu = 0.1763803548098221 and Mv = 0.03471729817167219
# At time 11 SE converged with well defined overlap = 4.668276877686068e-12
# SE iteration with snr=0.4202963352704008 and rho=0.5
# At time 0 we have deltau = 0.0005798801901325114 and deltav=0.0009117281742244237 and Mu = 0.00042011980986748866 and Mv = 8.827182577557626e-05
# At time 9 SE converged with well defined overlap = 1.5556989444133794e-12
# SE iteration with snr=0.42709816402730544 and rho=0.5
# At time 0 we have deltau = 0.8212001998600307 and deltav=0.46430008914968196 and Mu = 0.17879980013996927 and Mv = 0.03569991085031805
# At time 11 SE converged with well defined overlap = 6.50491854275469e-12
# SE iteration with snr=0.42709816402730544 and rho=0.5
# At time 0 we have deltau = 0.0005730841191114015 and deltav=0.0009088491209905809 and Mu = 0.00042691588088859854 and Mv = 9.115087900941909e-05
# At time 9 SE converged with well defined overlap = 2.043828166091252e-12
# SE iteration with snr=0.4338999927842101 and rho=0.5
# At time 0 we have deltau = 0.8187918357162484 and deltav=0.4633084331693092 and Mu = 0.1812081642837516 and Mv = 0.03669156683069078
# At time 11 SE converged with well defined overlap = 9.015579030719579e-12
# SE iteration with snr=0.4338999927842101 and rho=0.5
# At time 0 we have deltau = 0.0005662881404228816 and deltav=0.0009059239125854007 and Mu = 0.0004337118595771184 and Mv = 9.407608741459935e-05
# At time 9 SE converged with well defined overlap = 2.6735624507618188e-12
# SE iteration with snr=0.4407018215411148 and rho=0.5
# At time 0 we have deltau = 0.8163944574199236 and deltav=0.4623079111591636 and Mu = 0.1836055425800764 and Mv = 0.03769208884083643
# At time 12 SE converged with well defined overlap = 1.207102685175134e-12
# SE iteration with snr=0.4407018215411148 and rho=0.5
# At time 0 we have deltau = 0.0005594922540638197 and deltav=0.000902952551568657 and Mu = 0.00044050774593618037 and Mv = 9.704744843134298e-05
# At time 9 SE converged with well defined overlap = 3.482744946843815e-12
# SE iteration with snr=0.44750365029801936 and rho=0.5
# At time 0 we have deltau = 0.8140079710924769 and deltav=0.461298698909752 and Mu = 0.1859920289075231 and Mv = 0.03870130109024798
# At time 12 SE converged with well defined overlap = 1.7074323274937535e-12
# SE iteration with snr=0.44750365029801936 and rho=0.5
# At time 0 we have deltau = 0.0005526964600310821 and deltav=0.0008999350405254752 and Mu = 0.00044730353996891786 and Mv = 0.00010006495947452484
# At time 9 SE converged with well defined overlap = 4.518496796341621e-12
# SE iteration with snr=0.45430547905492413 and rho=0.5
# At time 0 we have deltau = 0.8116322842817967 and deltav=0.46028097076550495 and Mu = 0.18836771571820332 and Mv = 0.03971902923449503
# At time 12 SE converged with well defined overlap = 2.4022255672688637e-12
# SE iteration with snr=0.45430547905492413 and rho=0.5
# At time 0 we have deltau = 0.0005459007583215368 and deltav=0.0008968713820663241 and Mu = 0.00045409924167846323 and Mv = 0.00010312861793367586
# At time 9 SE converged with well defined overlap = 5.839293757399662e-12
# SE iteration with snr=0.4611073078118287 and rho=0.5
# At time 0 we have deltau = 0.8092673059294423 and deltav=0.45925489965966154 and Mu = 0.19073269407055773 and Mv = 0.040745100340338465
# At time 12 SE converged with well defined overlap = 3.362201375029993e-12
# SE iteration with snr=0.4611073078118287 and rho=0.5
# At time 0 we have deltau = 0.000539105148932051 and deltav=0.0008937615788270094 and Mu = 0.0004608948510679491 and Mv = 0.00010623842117299056
# At time 9 SE converged with well defined overlap = 7.517464867222872e-12
# SE iteration with snr=0.46790913656873345 and rho=0.5
# At time 0 we have deltau = 0.806912946338866 and deltav=0.4582206571484924 and Mu = 0.19308705366113402 and Mv = 0.041779342851507584
# At time 12 SE converged with well defined overlap = 4.682071462776753e-12
# SE iteration with snr=0.46790913656873345 and rho=0.5
# At time 0 we have deltau = 0.0005323096318594948 and deltav=0.0008906056334686658 and Mu = 0.0004676903681405053 and Mv = 0.00010939436653133426
# At time 10 SE converged with well defined overlap = 1.0555279983508051e-12
# SE iteration with snr=0.4747109653256381 and rho=0.5
# At time 0 we have deltau = 0.8045691171446157 and deltav=0.4571784134446981 and Mu = 0.19543088285538432 and Mv = 0.04282158655530191
# At time 12 SE converged with well defined overlap = 6.488123236615753e-12
# SE iteration with snr=0.4747109653256381 and rho=0.5
# At time 0 we have deltau = 0.0005255142071007346 and deltav=0.0008874035486777484 and Mu = 0.0004744857928992654 and Mv = 0.00011259645132225162
# At time 10 SE converged with well defined overlap = 1.3885103271752119e-12
# SE iteration with snr=0.48151279408254277 and rho=0.5
# At time 0 we have deltau = 0.8022357312824783 and deltav=0.4561283374498292 and Mu = 0.19776426871752176 and Mv = 0.043871662550170755
# At time 12 SE converged with well defined overlap = 8.948011764965322e-12
# SE iteration with snr=0.48151279408254277 and rho=0.5
# At time 0 we have deltau = 0.0005187188746526392 and deltav=0.0008841553271660262 and Mu = 0.00048128112534736076 and Mv = 0.0001158446728339738
# At time 10 SE converged with well defined overlap = 1.819424799252138e-12
# SE iteration with snr=0.4883146228394474 and rho=0.5
# At time 0 we have deltau = 0.799912702960528 and deltav=0.4550705967855924 and Mu = 0.20008729703947203 and Mv = 0.0449294032144076
# At time 13 SE converged with well defined overlap = 1.4644953758922207e-12
# SE iteration with snr=0.4883146228394474 and rho=0.5
# At time 0 we have deltau = 0.0005119236345120783 and deltav=0.000880860971670574 and Mu = 0.00048807636548792177 and Mv = 0.00011913902832942603
# At time 10 SE converged with well defined overlap = 2.375047362609933e-12
# SE iteration with snr=0.49511645159635204 and rho=0.5
# At time 0 we have deltau = 0.7975999476310458 and deltav=0.45400535782391493 and Mu = 0.20240005236895425 and Mv = 0.04599464217608508
# At time 13 SE converged with well defined overlap = 2.057465302687004e-12
# SE iteration with snr=0.49511645159635204 and rho=0.5
# At time 0 we have deltau = 0.0005051284866759199 and deltav=0.0008775204849537637 and Mu = 0.0004948715133240801 and Mv = 0.0001224795150462363
# At time 10 SE converged with well defined overlap = 3.0889378137312393e-12
# SE iteration with snr=0.5019182803532568 and rho=0.5
# At time 0 we have deltau = 0.7952973819632752 and deltav=0.4529327857156575 and Mu = 0.2047026180367249 and Mv = 0.04706721428434252
# At time 13 SE converged with well defined overlap = 2.8767613069539983e-12
# SE iteration with snr=0.5019182803532568 and rho=0.5
# At time 0 we have deltau = 0.0004983334311410328 and deltav=0.0008741338698032571 and Mu = 0.0005016665688589672 and Mv = 0.00012586613019674288
# At time 10 SE converged with well defined overlap = 4.003026577737154e-12
# SE iteration with snr=0.5087201091101614 and rho=0.5
# At time 0 we have deltau = 0.7930049238169834 and deltav=0.4518530444178739 and Mu = 0.20699507618301663 and Mv = 0.048146955582126116
# At time 13 SE converged with well defined overlap = 4.003655183254196e-12
# SE iteration with snr=0.5087201091101614 and rho=0.5
# At time 0 we have deltau = 0.0004915384679042881 and deltav=0.0008707011290319981 and Mu = 0.0005084615320957119 and Mv = 0.00012929887096800198
# At time 10 SE converged with well defined overlap = 5.169536414931262e-12
# SE iteration with snr=0.5155219378670661 and rho=0.5
# At time 0 we have deltau = 0.7907224922167992 and deltav=0.45076629671953516 and Mu = 0.20927750778320073 and Mv = 0.04923370328046486
# At time 13 SE converged with well defined overlap = 5.546813465940192e-12
# SE iteration with snr=0.5155219378670661 and rho=0.5
# At time 0 we have deltau = 0.0004847435969625542 and deltav=0.000867222265478203 and Mu = 0.0005152564030374458 and Mv = 0.00013277773452179703
# At time 10 SE converged with well defined overlap = 6.6533420900671025e-12
# SE iteration with snr=0.5223237666239707 and rho=0.5
# At time 0 we have deltau = 0.7884500073272962 and deltav=0.44967270426564077 and Mu = 0.21154999267270386 and Mv = 0.050327295734359206
# At time 13 SE converged with well defined overlap = 7.650933366448226e-12
# SE iteration with snr=0.5223237666239707 and rho=0.5
# At time 0 we have deltau = 0.0004779488183127012 and deltav=0.0008636972820053539 and Mu = 0.0005220511816872988 and Mv = 0.0001363027179946461
# At time 10 SE converged with well defined overlap = 8.5347613789787e-12
# SE iteration with snr=0.5291255953808754 and rho=0.5
# At time 0 we have deltau = 0.7861873904287947 and deltav=0.44857242757965937 and Mu = 0.21381260957120526 and Mv = 0.051427572420340635
# At time 14 SE converged with well defined overlap = 1.4709801697823979e-12
# SE iteration with snr=0.5291255953808754 and rho=0.5
# At time 0 we have deltau = 0.00047115413195159895 and deltav=0.0008601261815021895 and Mu = 0.0005288458680484011 and Mv = 0.0001398738184978106
# At time 11 SE converged with well defined overlap = 1.5276766085023923e-12
# SE iteration with snr=0.5359274241377799 and rho=0.5
# At time 0 we have deltau = 0.7839345638938596 and deltav=0.4474656260842492 and Mu = 0.2160654361061404 and Mv = 0.05253437391575077
# At time 14 SE converged with well defined overlap = 2.063883014873108e-12
# SE iteration with snr=0.5359274241377799 and rho=0.5
# At time 0 we have deltau = 0.00046435953787611714 and deltav=0.0008565089668826965 and Mu = 0.0005356404621238829 and Mv = 0.00014349103311730356
# At time 11 SE converged with well defined overlap = 1.997625254501232e-12
# SE iteration with snr=0.5427292528946848 and rho=0.5
# At time 0 we have deltau = 0.7816914511644617 and deltav=0.446352458120222 and Mu = 0.21830854883553827 and Mv = 0.05364754187977797
# At time 14 SE converged with well defined overlap = 2.8830202851644577e-12
# SE iteration with snr=0.5427292528946848 and rho=0.5
# At time 0 we have deltau = 0.0004575650360831282 and deltav=0.0008528456410861021 and Mu = 0.0005424349639168718 and Mv = 0.0001471543589138979
# At time 11 SE converged with well defined overlap = 2.603318326502268e-12
# SE iteration with snr=0.5495310816515895 and rho=0.5
# At time 0 we have deltau = 0.7794579767297869 and deltav=0.44523308096372516 and Mu = 0.22054202327021305 and Mv = 0.05476691903627487
# At time 14 SE converged with well defined overlap = 4.009971101046097e-12
# SE iteration with snr=0.5495310816515895 and rho=0.5
# At time 0 we have deltau = 0.0004507706265694995 and deltav=0.0008491362070768638 and Mu = 0.0005492293734305005 and Mv = 0.00015086379292313627
# At time 11 SE converged with well defined overlap = 3.381487534730909e-12
# SE iteration with snr=0.5563329104084941 and rho=0.5
# At time 0 we have deltau = 0.7772340661046637 and deltav=0.44410765084162734 and Mu = 0.22276593389533622 and Mv = 0.05589234915837267
# At time 14 SE converged with well defined overlap = 5.554059469259592e-12
# SE iteration with snr=0.5563329104084941 and rho=0.5
# At time 0 we have deltau = 0.0004439763093321052 and deltav=0.0008453806678446627 and Mu = 0.0005560236906678948 and Mv = 0.00015461933215533732
# At time 11 SE converged with well defined overlap = 4.378151734089928e-12
# SE iteration with snr=0.5631347391653988 and rho=0.5
# At time 0 we have deltau = 0.7750196458085908 and deltav=0.44297632294510453 and Mu = 0.2249803541914092 and Mv = 0.05702367705489547
# At time 14 SE converged with well defined overlap = 7.661233498693514e-12
# SE iteration with snr=0.5631347391653988 and rho=0.5
# At time 0 we have deltau = 0.00043718208436781573 and deltav=0.000841579026404393 and Mu = 0.0005628179156321843 and Mv = 0.00015842097359560704
# At time 11 SE converged with well defined overlap = 5.650804578654918e-12
# SE iteration with snr=0.5699365679223034 and rho=0.5
# At time 0 we have deltau = 0.7728146433453423 and deltav=0.4418392514414313 and Mu = 0.2271853566546577 and Mv = 0.05816074855856865
# At time 15 SE converged with well defined overlap = 1.7095089654364716e-12
# SE iteration with snr=0.5699365679223034 and rho=0.5
# At time 0 we have deltau = 0.00043038795167350103 and deltav=0.0008377312857961533 and Mu = 0.000569612048326499 and Mv = 0.00016226871420384667
# At time 11 SE converged with well defined overlap = 7.2710806933340775e-12
# SE iteration with snr=0.5767383966792081 and rho=0.5
# At time 0 we have deltau = 0.7706189871831312 and deltav=0.44069658948399326 and Mu = 0.22938101281686882 and Mv = 0.05930341051600674
# At time 15 SE converged with well defined overlap = 2.3956602256232612e-12
# SE iteration with snr=0.5767383966792081 and rho=0.5
# At time 0 we have deltau = 0.0004235939112460336 and deltav=0.000833837449085239 and Mu = 0.0005764060887539664 and Mv = 0.00016616255091476102
# At time 12 SE converged with well defined overlap = 1.5513762665421837e-12
# SE iteration with snr=0.5835402254361126 and rho=0.5
# At time 0 we have deltau = 0.7684326067353109 and deltav=0.439548489220543 and Mu = 0.23156739326468917 and Mv = 0.06045151077945698
# At time 15 SE converged with well defined overlap = 3.343465582850613e-12
# SE iteration with snr=0.5835402254361126 and rho=0.5
# At time 0 we have deltau = 0.0004167999630822865 and deltav=0.0008298975193621323 and Mu = 0.0005832000369177135 and Mv = 0.00017010248063786766
# At time 12 SE converged with well defined overlap = 2.0315226875308486e-12
# SE iteration with snr=0.5903420541930174 and rho=0.5
# At time 0 we have deltau = 0.7662554323415965 and deltav=0.4383951017997332 and Mu = 0.23374456765840346 and Mv = 0.0616048982002668
# At time 15 SE converged with well defined overlap = 4.647585574864409e-12
# SE iteration with snr=0.5903420541930174 and rho=0.5
# At time 0 we have deltau = 0.00041000610717912883 and deltav=0.0008259114997424921 and Mu = 0.0005899938928208712 and Mv = 0.00017408850025750798
# At time 12 SE converged with well defined overlap = 2.651971276518135e-12
# SE iteration with snr=0.5971438829499219 and rho=0.5
# At time 0 we have deltau = 0.7640873952497909 and deltav=0.437236577375964 and Mu = 0.23591260475020914 and Mv = 0.06276342262403597
# At time 15 SE converged with well defined overlap = 6.435087706099627e-12
# SE iteration with snr=0.5971438829499219 and rho=0.5
# At time 0 we have deltau = 0.00040321234353343663 and deltav=0.0008218793933671476 and Mu = 0.0005967876564665634 and Mv = 0.0001781206066328524
# At time 12 SE converged with well defined overlap = 3.4513551699748636e-12
# SE iteration with snr=0.6039457117068268 and rho=0.5
# At time 0 we have deltau = 0.761928427597992 and deltav=0.4360730651125912 and Mu = 0.23807157240200807 and Mv = 0.06392693488740882
# At time 15 SE converged with well defined overlap = 8.875980438353498e-12
# SE iteration with snr=0.6039457117068268 and rho=0.5
# At time 0 we have deltau = 0.0003964186721420789 and deltav=0.0008178012034020853 and Mu = 0.0006035813278579211 and Mv = 0.0001821987965979147
# At time 12 SE converged with well defined overlap = 4.478305309467883e-12
# SE iteration with snr=0.6107475404637315 and rho=0.5
# At time 0 we have deltau = 0.7597784623972736 and deltav=0.434904713183547 and Mu = 0.24022153760272633 and Mv = 0.06509528681645299
# At time 16 SE converged with well defined overlap = 2.274798801963822e-12
# SE iteration with snr=0.6107475404637315 and rho=0.5
# At time 0 we have deltau = 0.0003896250930019307 and deltav=0.0008136769330384433 and Mu = 0.0006103749069980693 and Mv = 0.00018632306696155667
# At time 12 SE converged with well defined overlap = 5.7939005037086995e-12
# SE iteration with snr=0.6175493692206361 and rho=0.5
# At time 0 we have deltau = 0.7576374335148174 and deltav=0.4337316687734305 and Mu = 0.24236256648518262 and Mv = 0.06626833122656947
# At time 16 SE converged with well defined overlap = 3.1841990988428838e-12
# SE iteration with snr=0.6175493692206361 and rho=0.5
# At time 0 we have deltau = 0.00038283160610986394 and deltav=0.0008095065854924993 and Mu = 0.0006171683938901361 and Mv = 0.0001904934145075007
# At time 12 SE converged with well defined overlap = 7.474621253931709e-12
# SE iteration with snr=0.6243511979775408 and rho=0.5
# At time 0 we have deltau = 0.7555052756574834 and deltav=0.43255407807612983 and Mu = 0.24449472434251665 and Mv = 0.06744592192387017
# At time 16 SE converged with well defined overlap = 4.4400799432509936e-12
# SE iteration with snr=0.6243511979775408 and rho=0.5
# At time 0 we have deltau = 0.0003760382114627519 and deltav=0.0008052901640056619 and Mu = 0.0006239617885372481 and Mv = 0.0001947098359943382
# At time 13 SE converged with well defined overlap = 1.874235747670097e-12
# SE iteration with snr=0.6311530267344453 and rho=0.5
# At time 0 we have deltau = 0.753381924355806 and deltav=0.43137208629204243 and Mu = 0.24661807564419405 and Mv = 0.06862791370795758
# At time 16 SE converged with well defined overlap = 6.168072700825709e-12
# SE iteration with snr=0.6311530267344453 and rho=0.5
# At time 0 we have deltau = 0.0003692449090574667 and deltav=0.0008010276718444604 and Mu = 0.0006307550909425333 and Mv = 0.0001989723281555396
# At time 13 SE converged with well defined overlap = 2.4572849656409884e-12
# SE iteration with snr=0.6379548554913501 and rho=0.5
# At time 0 we have deltau = 0.7512673159483991 and deltav=0.43018583762396334 and Mu = 0.24873268405160087 and Mv = 0.06981416237603666
# At time 16 SE converged with well defined overlap = 8.537080724090456e-12
# SE iteration with snr=0.6379548554913501 and rho=0.5
# At time 0 we have deltau = 0.00036245169889088404 and deltav=0.0007967191123005373 and Mu = 0.000637548301109116 and Mv = 0.00020328088769946273
# At time 13 SE converged with well defined overlap = 3.2123736683045163e-12
# SE iteration with snr=0.6447566842482546 and rho=0.5
# At time 0 we have deltau = 0.7491613875667599 and deltav=0.42899547527171467 and Mu = 0.2508386124332401 and Mv = 0.07100452472828532
# At time 17 SE converged with well defined overlap = 2.447184897180154e-12
# SE iteration with snr=0.6447566842482546 and rho=0.5
# At time 0 we have deltau = 0.0003556585809598768 and deltav=0.0007923644886906355 and Mu = 0.0006443414190401232 and Mv = 0.00020763551130936444
# At time 13 SE converged with well defined overlap = 4.187570005117243e-12
# SE iteration with snr=0.6515585130051594 and rho=0.5
# At time 0 we have deltau = 0.7470640771204544 and deltav=0.427801141425591 and Mu = 0.25293592287954564 and Mv = 0.072198858574409
# At time 17 SE converged with well defined overlap = 3.4343323190964593e-12
# SE iteration with snr=0.6515585130051594 and rho=0.5
# At time 0 we have deltau = 0.0003488655552613178 and deltav=0.0007879638043565896 and Mu = 0.0006511344447386822 and Mv = 0.00021203619564341038
# At time 13 SE converged with well defined overlap = 5.443641250754264e-12
# SE iteration with snr=0.6583603417620639 and rho=0.5
# At time 0 we have deltau = 0.7449753232826786 and deltav=0.42660297725869967 and Mu = 0.2550246767173214 and Mv = 0.07339702274130036
# At time 17 SE converged with well defined overlap = 4.8019635543937894e-12
# SE iteration with snr=0.6583603417620639 and rho=0.5
# At time 0 we have deltau = 0.00034207262179208376 and deltav=0.0007835170626653176 and Mu = 0.0006579273782079163 and Mv = 0.00021648293733468244
# At time 13 SE converged with well defined overlap = 7.057215821333886e-12
# SE iteration with snr=0.6651621705189686 and rho=0.5
# At time 0 we have deltau = 0.7428950654761767 and deltav=0.42540112291827287 and Mu = 0.2571049345238233 and Mv = 0.07459887708172713
# At time 17 SE converged with well defined overlap = 6.69004092547012e-12
# SE iteration with snr=0.6651621705189686 and rho=0.5
# At time 0 we have deltau = 0.00033527978054904734 and deltav=0.0007790242670088074 and Mu = 0.0006647202194509527 and Mv = 0.0002209757329911926
# At time 13 SE converged with well defined overlap = 9.124689769468081e-12
# SE iteration with snr=0.6719639992758735 and rho=0.5
# At time 0 we have deltau = 0.7408232438595104 and deltav=0.424195717516034 and Mu = 0.2591767561404896 and Mv = 0.075804282483966
# At time 17 SE converged with well defined overlap = 9.287567964594815e-12
# SE iteration with snr=0.6719639992758735 and rho=0.5
# At time 0 we have deltau = 0.0003284870315290831 and deltav=0.0007744854208041098 and Mu = 0.0006715129684709169 and Mv = 0.0002255145791958903
# At time 14 SE converged with well defined overlap = 2.6566247637956714e-12
# SE iteration with snr=0.678765828032778 and rho=0.5
# At time 0 we have deltau = 0.7387597993136659 and deltav=0.4229868991176964 and Mu = 0.2612402006863342 and Mv = 0.07701310088230359
# At time 18 SE converged with well defined overlap = 2.9599130154183786e-12
# SE iteration with snr=0.678765828032778 and rho=0.5
# At time 0 we have deltau = 0.0003216943747290673 and deltav=0.000769900527493327 and Mu = 0.0006783056252709327 and Mv = 0.00023009947250667297
# At time 14 SE converged with well defined overlap = 3.4866992016753885e-12
# SE iteration with snr=0.6855676567896828 and rho=0.5
# At time 0 we have deltau = 0.7367046734289875 and deltav=0.42177480473167683 and Mu = 0.26329532657101257 and Mv = 0.07822519526832318
# At time 18 SE converged with well defined overlap = 4.163191901041464e-12
# SE iteration with snr=0.6855676567896828 and rho=0.5
# At time 0 we have deltau = 0.00031490181014587446 and deltav=0.0007652695905436023 and Mu = 0.0006850981898541256 and Mv = 0.00023473040945639774
# At time 14 SE converged with well defined overlap = 4.563735014726083e-12
# SE iteration with snr=0.6923694855465873 and rho=0.5
# At time 0 we have deltau = 0.7346578084924302 and deltav=0.4205595702971034 and Mu = 0.26534219150756977 and Mv = 0.07944042970289661
# At time 18 SE converged with well defined overlap = 5.83496021531365e-12
# SE iteration with snr=0.6923694855465873 and rho=0.5
# At time 0 we have deltau = 0.0003081093377763799 and deltav=0.0007605926134471096 and Mu = 0.0006918906622236201 and Mv = 0.0002394073865528905
# At time 14 SE converged with well defined overlap = 5.9576135698275695e-12
# SE iteration with snr=0.6991713143034921 and rho=0.5
# At time 0 we have deltau = 0.7326191474751194 and deltav=0.41934133067119767 and Mu = 0.2673808525248806 and Mv = 0.08065866932880233
# At time 18 SE converged with well defined overlap = 8.149693974929372e-12
# SE iteration with snr=0.6991713143034921 and rho=0.5
# At time 0 we have deltau = 0.00030131695761745846 and deltav=0.0007558695997210427 and Mu = 0.0006986830423825416 and Mv = 0.00024413040027895734
# At time 14 SE converged with well defined overlap = 7.756972413147368e-12
# SE iteration with snr=0.7059731430603966 and rho=0.5
# At time 0 we have deltau = 0.7305886340202089 and deltav=0.4181202196161107 and Mu = 0.2694113659797911 and Mv = 0.08187978038388935
# At time 19 SE converged with well defined overlap = 2.8269044460218067e-12
# SE iteration with snr=0.7059731430603966 and rho=0.5
# At time 0 we have deltau = 0.0002945246696659867 and deltav=0.0007511005529076063 and Mu = 0.0007054753303340133 and Mv = 0.0002488994470923937
# At time 15 SE converged with well defined overlap = 2.5104376615822114e-12
# SE iteration with snr=0.7127749718173013 and rho=0.5
# At time 0 we have deltau = 0.7285662124310281 and deltav=0.41689636978528855 and Mu = 0.27143378756897185 and Mv = 0.08310363021471147
# At time 19 SE converged with well defined overlap = 3.997687990622871e-12
# SE iteration with snr=0.7127749718173013 and rho=0.5
# At time 0 we have deltau = 0.00028773247391884 and deltav=0.0007462854765740031 and Mu = 0.00071226752608116 and Mv = 0.0002537145234259969
# At time 15 SE converged with well defined overlap = 3.3151143175050676e-12
# SE iteration with snr=0.7195768005742059 and rho=0.5
# At time 0 we have deltau = 0.7265518276595113 and deltav=0.4156699127094465 and Mu = 0.2734481723404887 and Mv = 0.08433008729055352
# At time 19 SE converged with well defined overlap = 5.633779244099633e-12
# SE iteration with snr=0.7195768005742059 and rho=0.5
# At time 0 we have deltau = 0.0002809403703728948 and deltav=0.0007414243743124249 and Mu = 0.0007190596296271052 and Mv = 0.0002585756256875751
# At time 15 SE converged with well defined overlap = 4.366171693044442e-12
# SE iteration with snr=0.7263786293311106 and rho=0.5
# At time 0 we have deltau = 0.7245454252948976 and deltav=0.41444097878222275 and Mu = 0.2754545747051024 and Mv = 0.08555902121777728
# At time 19 SE converged with well defined overlap = 7.912442891905238e-12
# SE iteration with snr=0.7263786293311106 and rho=0.5
# At time 0 we have deltau = 0.00027414835902502823 and deltav=0.0007365172497400413 and Mu = 0.0007258516409749718 and Mv = 0.00026348275025995876
# At time 15 SE converged with well defined overlap = 5.735581316716181e-12
# SE iteration with snr=0.7331804580880155 and rho=0.5
# At time 0 we have deltau = 0.7225469515526965 and deltav=0.4132096972455866 and Mu = 0.27745304844730345 and Mv = 0.08679030275441339
# At time 20 SE converged with well defined overlap = 2.976866100531537e-12
# SE iteration with snr=0.7331804580880155 and rho=0.5
# At time 0 we have deltau = 0.00026735643987211536 and deltav=0.0007315641064989872 and Mu = 0.0007326435601278847 and Mv = 0.0002684358935010128
# At time 15 SE converged with well defined overlap = 7.515352819951122e-12
# SE iteration with snr=0.73998228684492 and rho=0.5
# At time 0 we have deltau = 0.7205563532639093 and deltav=0.4119761961750698 and Mu = 0.2794436467360907 and Mv = 0.08802380382493018
# At time 20 SE converged with well defined overlap = 4.230653769590578e-12
# SE iteration with snr=0.73998228684492 and rho=0.5
# At time 0 we have deltau = 0.000260564612911035 and deltav=0.0007265649482563555 and Mu = 0.000739435387088965 and Mv = 0.0002734350517436446
# At time 15 SE converged with well defined overlap = 9.822838321615074e-12
# SE iteration with snr=0.7467841156018248 and rho=0.5
# At time 0 we have deltau = 0.7185735778644995 and deltav=0.41074060246488864 and Mu = 0.28142642213550056 and Mv = 0.08925939753511133
# At time 20 SE converged with well defined overlap = 5.992078157532274e-12
# SE iteration with snr=0.7467841156018248 and rho=0.5
# ...
# SE iteration with snr=3.331479043225597 and rho=0.5
# At time 0 we have deltau = 0.0023204413883784647 and deltav=0.0044714365148201506 and Mu = 0.0033204413883784647 and Mv = 0.005471436514820151
# At time 18 SE converged with well defined overlap = 0.6040560309013389
# SE iteration with snr=3.3382808719825023 and rho=0.5
# At time 0 we have deltau = 0.2859845345249793 and deltav=0.1269954694942172 and Mu = 0.7140154654750207 and Mv = 0.3730045305057828
# At time 14 SE converged with well defined overlap = 0.605086624933502
# SE iteration with snr=3.3382808719825023 and rho=0.5
# At time 0 we have deltau = 0.002327198224490709 and deltav=0.004493526571326106 and Mu = 0.003327198224490709 and Mv = 0.005493526571326106
# At time 18 SE converged with well defined overlap = 0.6050866249197304
# SE iteration with snr=3.3450827007394066 and rho=0.5
# At time 0 we have deltau = 0.2853497198679027 and deltav=0.12669862911063956 and Mu = 0.7146502801320973 and Mv = 0.37330137088936044
# At time 14 SE converged with well defined overlap = 0.6061136363772269
# SE iteration with snr=3.3450827007394066 and rho=0.5
# At time 0 we have deltau = 0.0023339549695913548 and deltav=0.004515659573039998 and Mu = 0.0033339549695913548 and Mv = 0.005515659573039998
# At time 18 SE converged with well defined overlap = 0.6061136363643612
# SE iteration with snr=3.3518845294963113 and rho=0.5
# At time 0 we have deltau = 0.284716495447053 and deltav=0.1264029786500772 and Mu = 0.715283504552947 and Mv = 0.3735970213499228
# At time 14 SE converged with well defined overlap = 0.6071370840210845
# SE iteration with snr=3.3518845294963113 and rho=0.5
# At time 0 we have deltau = 0.0023407116236834427 and deltav=0.00453783550818321 and Mu = 0.0033407116236834427 and Mv = 0.00553783550818321
# At time 18 SE converged with well defined overlap = 0.6071370840090633
# SE iteration with snr=3.358686358253216 and rho=0.5
# At time 0 we have deltau = 0.28408485644435877 and deltav=0.12610851192746225 and Mu = 0.7159151435556412 and Mv = 0.37389148807253775
# At time 14 SE converged with well defined overlap = 0.608156986490284
# SE iteration with snr=3.358686358253216 and rho=0.5
# At time 0 we have deltau = 0.002347468186770016 and deltav=0.004560054364961105 and Mu = 0.003347468186770016 and Mv = 0.005560054364961105
# At time 18 SE converged with well defined overlap = 0.6081569864790499
# SE iteration with snr=3.3654881870101208 and rho=0.5
# At time 0 we have deltau = 0.28345479806074625 and deltav=0.12581522279431617 and Mu = 0.7165452019392538 and Mv = 0.3741847772056838
# At time 14 SE converged with well defined overlap = 0.609173362263039
# SE iteration with snr=3.3654881870101208 and rho=0.5
# At time 0 we have deltau = 0.0023542246588541104 and deltav=0.004582316131563054 and Mu = 0.0033542246588541104 and Mv = 0.005582316131563054
# At time 18 SE converged with well defined overlap = 0.609173362252539
# SE iteration with snr=3.3722900157670255 and rho=0.5
# At time 0 we have deltau = 0.28282631551603965 and deltav=0.12552310513853726 and Mu = 0.7171736844839603 and Mv = 0.37447689486146274
# At time 14 SE converged with well defined overlap = 0.610186229672168
# SE iteration with snr=3.3722900157670255 and rho=0.5
# At time 0 we have deltau = 0.00236098103993877 and deltav=0.0046046207961624695 and Mu = 0.00336098103993877 and Mv = 0.0056046207961624695
# At time 18 SE converged with well defined overlap = 0.6101862296623523
# SE iteration with snr=3.37909184452393 and rho=0.5
# At time 0 we have deltau = 0.28219940404885946 and deltav=0.12523215288418876 and Mu = 0.7178005959511405 and Mv = 0.37476784711581124
# At time 14 SE converged with well defined overlap = 0.6111956069066706
# SE iteration with snr=3.37909184452393 and rho=0.5
# At time 0 we have deltau = 0.00236773733002703 and deltav=0.004626968346916834 and Mu = 0.00336773733002703 and Mv = 0.005626968346916834
# At time 18 SE converged with well defined overlap = 0.6111956068974934
# SE iteration with snr=3.3858936732808345 and rho=0.5
# At time 0 we have deltau = 0.28157405891652443 and deltav=0.124942359991288 and Mu = 0.7184259410834756 and Mv = 0.375057640008712
# At time 14 SE converged with well defined overlap = 0.6122015120132853
# SE iteration with snr=3.3858936732808345 and rho=0.5
# At time 0 we have deltau = 0.002374493529121937 and deltav=0.004649358771967743 and Mu = 0.003374493529121937 and Mv = 0.005649358771967743
# At time 18 SE converged with well defined overlap = 0.6122015120047037
# SE iteration with snr=3.3926955020377396 and rho=0.5
# At time 0 we have deltau = 0.28095027539495165 and deltav=0.12465372045559597 and Mu = 0.7190497246050483 and Mv = 0.375346279544404
# At time 14 SE converged with well defined overlap = 0.6132039628980226
# SE iteration with snr=3.3926955020377396 and rho=0.5
# At time 0 we have deltau = 0.002381249637226524 and deltav=0.004671792059440909 and Mu = 0.003381249637226524 and Mv = 0.005671792059440909
# At time 18 SE converged with well defined overlap = 0.6132039628899968
# SE iteration with snr=3.399497330794644 and rho=0.5
# At time 0 we have deltau = 0.2803280487785592 and deltav=0.12436622830840788 and Mu = 0.7196719512214408 and Mv = 0.3756337716915921
# At time 14 SE converged with well defined overlap = 0.6142029773276796
# SE iteration with snr=3.399497330794644 and rho=0.5
# At time 0 we have deltau = 0.002388005654343829 and deltav=0.004694268197446208 and Mu = 0.003388005654343829 and Mv = 0.005694268197446208
# At time 18 SE converged with well defined overlap = 0.6142029773201721
# SE iteration with snr=3.406299159551549 and rho=0.5
# At time 0 we have deltau = 0.2797073743801679 and deltav=0.1240798776163442 and Mu = 0.7202926256198321 and Mv = 0.3759201223836558
# At time 14 SE converged with well defined overlap = 0.615198572931332
# SE iteration with snr=3.406299159551549 and rho=0.5
# At time 0 we have deltau = 0.0023947615804768988 and deltav=0.004716787174077734 and Mu = 0.003394761580476899 and Mv = 0.005716787174077734
# At time 18 SE converged with well defined overlap = 0.6151985729243086
# SE iteration with snr=3.4131009883084533 and rho=0.5
# At time 0 we have deltau = 0.27908824753090533 and deltav=0.12379466248114301 and Mu = 0.7209117524690947 and Mv = 0.376205337518857
# At time 14 SE converged with well defined overlap = 0.6161907672018075
# SE iteration with snr=3.4131009883084533 and rho=0.5
# At time 0 we have deltau = 0.002401517415628763 and deltav=0.0047393489774137645 and Mu = 0.003401517415628763 and Mv = 0.0057393489774137645
# At time 18 SE converged with well defined overlap = 0.6161907671952359
# SE iteration with snr=3.419902817065358 and rho=0.5
# At time 0 we have deltau = 0.2784706635801093 and deltav=0.12351057703945223 and Mu = 0.7215293364198907 and Mv = 0.37648942296054777
# At time 14 SE converged with well defined overlap = 0.6171795774971387
# SE iteration with snr=3.419902817065358 and rho=0.5
# At time 0 we have deltau = 0.0024082731598024684 and deltav=0.0047619535955168695 and Mu = 0.0034082731598024684 and Mv = 0.0057619535955168695
# At time 18 SE converged with well defined overlap = 0.6171795774909887
# SE iteration with snr=3.4267046458222628 and rho=0.5
# At time 0 we have deltau = 0.277854617895232 and deltav=0.12322761546262379 and Mu = 0.722145382104768 and Mv = 0.3767723845373762
# At time 14 SE converged with well defined overlap = 0.6181650210419948
# SE iteration with snr=3.4267046458222628 and rho=0.5
# At time 0 we have deltau = 0.0024150288130010454 and deltav=0.0047846010164338745 and Mu = 0.0034150288130010455 and Mv = 0.0057846010164338746
# At time 18 SE converged with well defined overlap = 0.6181650210362384
# SE iteration with snr=3.4335064745791675 and rho=0.5
# At time 0 we have deltau = 0.2772401058617463 and deltav=0.12294577195650747 and Mu = 0.7227598941382537 and Mv = 0.37705422804349253
# At time 14 SE converged with well defined overlap = 0.619147114929096
# SE iteration with snr=3.4335064745791675 and rho=0.5
# At time 0 we have deltau = 0.0024217843752275393 and deltav=0.00480729122819594 and Mu = 0.0034217843752275393 and Mv = 0.00580729122819594
# At time 18 SE converged with well defined overlap = 0.6191471149237076
# SE iteration with snr=3.440308303336072 and rho=0.5
# At time 0 we have deltau = 0.2766271228830507 and deltav=0.12266504076124674 and Mu = 0.7233728771169493 and Mv = 0.37733495923875326
# At time 14 SE converged with well defined overlap = 0.6201258761206087
# SE iteration with snr=3.440308303336072 and rho=0.5
# At time 0 we have deltau = 0.0024285398464849823 and deltav=0.004830024218818557 and Mu = 0.0034285398464849823 and Mv = 0.005830024218818557
# At time 18 SE converged with well defined overlap = 0.6201258761155637
# SE iteration with snr=3.447110132092977 and rho=0.5
# At time 0 we have deltau = 0.27601566438037595 and deltav=0.1223854161510739 and Mu = 0.723984335619624 and Mv = 0.3776145838489261
# At time 14 SE converged with well defined overlap = 0.6211013214495202
# SE iteration with snr=3.447110132092977 and rho=0.5
# At time 0 we have deltau = 0.0024352952267764167 and deltav=0.004852799976301605 and Mu = 0.0034352952267764168 and Mv = 0.005852799976301605
# At time 18 SE converged with well defined overlap = 0.6211013214447961
# SE iteration with snr=3.453911960849881 and rho=0.5
# At time 0 we have deltau = 0.27540572579269285 and deltav=0.12210689243410755 and Mu = 0.7245942742073072 and Mv = 0.37789310756589245
# At time 14 SE converged with well defined overlap = 0.6220734676209971
# SE iteration with snr=3.453911960849881 and rho=0.5
# At time 0 we have deltau = 0.0024420505161048735 and deltav=0.004875618488629349 and Mu = 0.0034420505161048736 and Mv = 0.005875618488629349
# At time 18 SE converged with well defined overlap = 0.6220734676165728
# SE iteration with snr=3.4607137896067863 and rho=0.5
# At time 0 we have deltau = 0.27479730257661883 and deltav=0.12182946395215027 and Mu = 0.7252026974233812 and Mv = 0.3781705360478497
# At time 14 SE converged with well defined overlap = 0.6230423312137242
# SE iteration with snr=3.4607137896067863 and rho=0.5
# At time 0 we have deltau = 0.002448805714473397 and deltav=0.004898479743770528 and Mu = 0.003448805714473397 and Mv = 0.005898479743770528
# At time 18 SE converged with well defined overlap = 0.6230423312095802
# SE iteration with snr=3.4675156183636906 and rho=0.5
# At time 0 we have deltau = 0.27419039020632785 and deltav=0.12155312508048649 and Mu = 0.7258096097936722 and Mv = 0.3784468749195135
# At time 14 SE converged with well defined overlap = 0.624007928681226
# SE iteration with snr=3.4675156183636906 and rho=0.5
# At time 0 we have deltau = 0.002455560821885021 and deltav=0.004921383729678306 and Mu = 0.003455560821885021 and Mv = 0.005921383729678306
# At time 18 SE converged with well defined overlap = 0.6240079286773439
# SE iteration with snr=3.474317447120595 and rho=0.5
# At time 0 we have deltau = 0.2735849841734582 and deltav=0.12127787022768288 and Mu = 0.7264150158265418 and Mv = 0.3787221297723171
# At time 14 SE converged with well defined overlap = 0.6249702763531709
# SE iteration with snr=3.474317447120595 and rho=0.5
# At time 0 we have deltau = 0.002462315838342783 and deltav=0.004944330434290374 and Mu = 0.003462315838342783 and Mv = 0.005944330434290374
# At time 18 SE converged with well defined overlap = 0.6249702763495335
# SE iteration with snr=3.4811192758775 and rho=0.5
# At time 0 we have deltau = 0.27298107998702303 and deltav=0.12100369383538745 and Mu = 0.727018920012977 and Mv = 0.37899630616461255
# At time 14 SE converged with well defined overlap = 0.6259293904366585
# SE iteration with snr=3.4811192758775 and rho=0.5
# At time 0 we have deltau = 0.0024690707638497207 and deltav=0.004967319845528939 and Mu = 0.0034690707638497208 and Mv = 0.005967319845528939
# At time 18 SE converged with well defined overlap = 0.6259293904332498
# SE iteration with snr=3.4879211046344047 and rho=0.5
# At time 0 we have deltau = 0.2723786731733201 and deltav=0.12073059037813139 and Mu = 0.7276213268266799 and Mv = 0.3792694096218686
# At time 14 SE converged with well defined overlap = 0.6268852870174878
# SE iteration with snr=3.4879211046344047 and rho=0.5
# At time 0 we have deltau = 0.0024758255984088646 and deltav=0.004990351951300759 and Mu = 0.0034758255984088647 and Mv = 0.005990351951300759
# At time 18 SE converged with well defined overlap = 0.6268852870142931
# SE iteration with snr=3.4947229333913095 and rho=0.5
# At time 0 we have deltau = 0.2717777592758426 and deltav=0.1204585543631308 and Mu = 0.7282222407241574 and Mv = 0.3795414456368692
# At time 14 SE converged with well defined overlap = 0.6278379820614115
# SE iteration with snr=3.4947229333913095 and rho=0.5
# At time 0 we have deltau = 0.00248258034202326 and deltav=0.005013426739497203 and Mu = 0.00348258034202326 and Mv = 0.006013426739497203
# At time 17 SE converged with well defined overlap = 0.6278379820502838
# SE iteration with snr=3.501524762148214 and rho=0.5
# At time 0 we have deltau = 0.2711783338551914 and deltav=0.12018758033008936 and Mu = 0.7288216661448086 and Mv = 0.37981241966991064
# At time 13 SE converged with well defined overlap = 0.6287874914238425
# SE iteration with snr=3.501524762148214 and rho=0.5
# At time 0 we have deltau = 0.0024893349946959334 and deltav=0.00503654419799423 and Mu = 0.0034893349946959334 and Mv = 0.00603654419799423
# At time 17 SE converged with well defined overlap = 0.6287874914049533
# SE iteration with snr=3.5083265909051184 and rho=0.5
# At time 0 we have deltau = 0.27058039248898635 and deltav=0.11991766285100214 and Mu = 0.7294196075110136 and Mv = 0.38008233714899786
# At time 13 SE converged with well defined overlap = 0.6297338308167539
# SE iteration with snr=3.5083265909051184 and rho=0.5
# At time 0 we have deltau = 0.002496089556429928 and deltav=0.00505970431465248 and Mu = 0.003496089556429928 and Mv = 0.00605970431465248
# At time 17 SE converged with well defined overlap = 0.6297338307989668
# SE iteration with snr=3.5151284196620236 and rho=0.5
# At time 0 we have deltau = 0.26998393077177907 and deltav=0.11964879652996024 and Mu = 0.7300160692282209 and Mv = 0.38035120347003976
# At time 13 SE converged with well defined overlap = 0.6306770158620477
# SE iteration with snr=3.5151284196620236 and rho=0.5
# At time 0 we have deltau = 0.0025028440272282775 and deltav=0.005082907077317255 and Mu = 0.0035028440272282775 and Mv = 0.006082907077317255
# At time 17 SE converged with well defined overlap = 0.6306770158452961
# SE iteration with snr=3.521930248418928 and rho=0.5
# At time 0 we have deltau = 0.26938894431496685 and deltav=0.11938097600295644 and Mu = 0.7306110556850332 and Mv = 0.38061902399704356
# At time 13 SE converged with well defined overlap = 0.6316170620574938
# SE iteration with snr=3.521930248418928 and rho=0.5
# At time 0 we have deltau = 0.002509598407094016 and deltav=0.005106152473818562 and Mu = 0.003509598407094016 and Mv = 0.006106152473818562
# At time 17 SE converged with well defined overlap = 0.6316170620417152
# SE iteration with snr=3.528732077175833 and rho=0.5
# At time 0 we have deltau = 0.2687954287467056 and deltav=0.11911419593769079 and Mu = 0.7312045712532944 and Mv = 0.3808858040623092
# At time 13 SE converged with well defined overlap = 0.63255398478684
# SE iteration with snr=3.528732077175833 and rho=0.5
# At time 0 we have deltau = 0.002516352696030177 and deltav=0.0051294404919711625 and Mu = 0.003516352696030177 and Mv = 0.0061294404919711625
# At time 17 SE converged with well defined overlap = 0.632553984771976
# SE iteration with snr=3.5355339059327373 and rho=0.5
# At time 0 we have deltau = 0.26820337971182484 and deltav=0.11884845103337893 and Mu = 0.7317966202881752 and Mv = 0.38115154896662107
# At time 13 SE converged with well defined overlap = 0.6334877993209691
# SE iteration with snr=3.5355339059327373 and rho=0.5
# At time 0 we have deltau = 0.0025231068940397994 and deltav=0.005152771119574586 and Mu = 0.0035231068940397995 and Mv = 0.006152771119574586
# At time 17 SE converged with well defined overlap = 0.6334877993069646

# %% [markdown]
# ##### $\color{Purple}{\text{Plots}}$

# %%
dimension = 1000 ; nsamples = 2000  ; rho = 0.5 ; damping = 0.7 ; alpha = 2 ; seeds = 10
coefs_amp = np.linspace(0.1,2.5,10)
amps = [] ; errs = [] 
for coef in coefs_amp:
    # Rescale the snr according to the sparsity level
    snr = coef/(rho*np.sqrt(alpha)) ; aux = []
    for seed in range(seeds):
        truth = get_instance(rho=rho, dimension=dimension, nsamples=nsamples, snr=snr)
        init = 1e-3*np.random.randn(nsamples) , 1e-3*np.random.randn(dimension)
        run = lowRAMP(truth,init, tol=1e-7, max_steps=500, snr=snr, rho=rho,damping=damping)
        if run[1]:
            # Store converged runs 
            aux.append(run[0])
    # Take mean and standard deviation over many iterations to access AMP performance
    errs.append(np.std(aux)/(np.sqrt(seeds))) ; amps.append(np.mean(aux))
# Out:
# AMP iteration with snr=0.1414213562373095 and rho = 0.5
# At iter = 0 we have diff = 1.8987440534060195e-06 and overlap=-2.235081836714573e-07
# At iter = 1 AMP converged with overlap=1.0802097725421709e-06
# AMP iteration with snr=0.1414213562373095 and rho = 0.5
# At iter = 0 we have diff = 2.0182132548743748e-06 and overlap=-1.5199846049156518e-06
# At iter = 1 AMP converged with overlap=-1.6006850232062627e-06
# AMP iteration with snr=0.1414213562373095 and rho = 0.5
# At iter = 0 we have diff = 1.971827365352019e-06 and overlap=1.598549872585058e-06
# At iter = 1 AMP converged with overlap=-2.8861915621880986e-06
# AMP iteration with snr=0.1414213562373095 and rho = 0.5
# At iter = 0 we have diff = 1.973817089632711e-06 and overlap=-1.415574185669124e-06
# At iter = 1 AMP converged with overlap=1.2769216988694939e-06
# AMP iteration with snr=0.1414213562373095 and rho = 0.5
# At iter = 0 we have diff = 1.9355118155805413e-06 and overlap=3.46943607401842e-07
# At iter = 1 AMP converged with overlap=2.184980190405857e-06
# AMP iteration with snr=0.1414213562373095 and rho = 0.5
# At iter = 0 we have diff = 1.8958794819615242e-06 and overlap=-8.55532925889267e-07
# At iter = 1 AMP converged with overlap=-1.143904845859292e-06
# AMP iteration with snr=0.1414213562373095 and rho = 0.5
# At iter = 0 we have diff = 1.9642880279311872e-06 and overlap=-4.882673650216455e-07
# At iter = 1 AMP converged with overlap=7.134278039803838e-07
# AMP iteration with snr=0.1414213562373095 and rho = 0.5
# At iter = 0 we have diff = 1.907893492901803e-06 and overlap=3.7051388591555904e-07
# At iter = 1 AMP converged with overlap=-3.088754806800484e-07
# AMP iteration with snr=0.1414213562373095 and rho = 0.5
# At iter = 0 we have diff = 1.9117003840405436e-06 and overlap=3.546291667243348e-07
# At iter = 1 AMP converged with overlap=3.852034469678133e-07
# AMP iteration with snr=0.1414213562373095 and rho = 0.5
# At iter = 0 we have diff = 1.97463822172991e-06 and overlap=-1.4932189322773518e-06
# At iter = 1 AMP converged with overlap=4.003883229720944e-07
# AMP iteration with snr=0.5185449728701349 and rho = 0.5
# At iter = 0 we have diff = 1.967296668747132e-06 and overlap=-1.4728919727416845e-06
# At iter = 2 AMP converged with overlap=-1.5646958701504761e-06
# AMP iteration with snr=0.5185449728701349 and rho = 0.5
# At iter = 0 we have diff = 1.7890713179342667e-06 and overlap=-3.7846044044742436e-06
# At iter = 2 AMP converged with overlap=4.532019815064255e-08
# AMP iteration with snr=0.5185449728701349 and rho = 0.5
# At iter = 0 we have diff = 2.0644859051331187e-06 and overlap=-1.3040597494390739e-06
# At iter = 2 AMP converged with overlap=5.846286559218058e-06
# AMP iteration with snr=0.5185449728701349 and rho = 0.5
# At iter = 0 we have diff = 1.9501782258766076e-06 and overlap=5.567505147631349e-08
# At iter = 2 AMP converged with overlap=1.7396651907161418e-06
# AMP iteration with snr=0.5185449728701349 and rho = 0.5
# At iter = 0 we have diff = 1.8660773023503583e-06 and overlap=-2.7974190378361566e-06
# At iter = 2 AMP converged with overlap=-3.334868144229281e-06
# AMP iteration with snr=0.5185449728701349 and rho = 0.5
# At iter = 0 we have diff = 1.8906519590712453e-06 and overlap=-1.4928934837040077e-06
# At iter = 2 AMP converged with overlap=-2.340492795852554e-08
# AMP iteration with snr=0.5185449728701349 and rho = 0.5
# At iter = 0 we have diff = 1.8233759232032627e-06 and overlap=-3.0573346798573045e-06
# At iter = 2 AMP converged with overlap=-3.131833997467795e-07
# AMP iteration with snr=0.5185449728701349 and rho = 0.5
# At iter = 0 we have diff = 1.8904574541157504e-06 and overlap=2.5540244579227875e-06
# At iter = 2 AMP converged with overlap=3.3570335614387346e-06
# AMP iteration with snr=0.5185449728701349 and rho = 0.5
# At iter = 0 we have diff = 1.8881250845155594e-06 and overlap=-1.0913517680674828e-07
# At iter = 2 AMP converged with overlap=-2.3010468514337866e-06
# AMP iteration with snr=0.5185449728701349 and rho = 0.5
# At iter = 0 we have diff = 1.9920480415621316e-06 and overlap=2.456003430862381e-07
# At iter = 2 AMP converged with overlap=-2.9235688276839642e-06
# AMP iteration with snr=0.8956685895029601 and rho = 0.5
# At iter = 0 we have diff = 1.8620016774884549e-06 and overlap=-1.1730302235136121e-05
# At iter = 3 AMP converged with overlap=-3.651166194959054e-06
# AMP iteration with snr=0.8956685895029601 and rho = 0.5
# At iter = 0 we have diff = 1.8052744886523362e-06 and overlap=4.989075075602369e-06
# At iter = 3 AMP converged with overlap=-3.88383361140821e-06
# AMP iteration with snr=0.8956685895029601 and rho = 0.5
# At iter = 0 we have diff = 1.737929547877516e-06 and overlap=9.701889158095353e-06
# At iter = 3 AMP converged with overlap=8.289089378046933e-06
# AMP iteration with snr=0.8956685895029601 and rho = 0.5
# At iter = 0 we have diff = 1.8399804666194825e-06 and overlap=-1.031396920778272e-06
# At iter = 3 AMP converged with overlap=-9.121470439020932e-07
# AMP iteration with snr=0.8956685895029601 and rho = 0.5
# At iter = 0 we have diff = 1.873211773452562e-06 and overlap=1.5714966241689764e-06
# At iter = 3 AMP converged with overlap=-1.0651925259266716e-05
# AMP iteration with snr=0.8956685895029601 and rho = 0.5
# At iter = 0 we have diff = 1.9081985368246823e-06 and overlap=-2.620331193566288e-08
# At iter = 3 AMP converged with overlap=3.0952913304798615e-06
# AMP iteration with snr=0.8956685895029601 and rho = 0.5
# At iter = 0 we have diff = 1.8984375900681706e-06 and overlap=3.7014634452403116e-06
# At iter = 3 AMP converged with overlap=1.4934726927891548e-05
# AMP iteration with snr=0.8956685895029601 and rho = 0.5
# At iter = 0 we have diff = 1.7741256463369416e-06 and overlap=1.914450018804871e-06
# At iter = 3 AMP converged with overlap=-1.4688315561040052e-05
# AMP iteration with snr=0.8956685895029601 and rho = 0.5
# At iter = 0 we have diff = 1.9165899842219024e-06 and overlap=-9.43866976167882e-06
# At iter = 3 AMP converged with overlap=1.6413571806264585e-06
# AMP iteration with snr=0.8956685895029601 and rho = 0.5
# At iter = 0 we have diff = 1.8195105363133694e-06 and overlap=-7.659693969801323e-06
# At iter = 3 AMP converged with overlap=-3.808922717512507e-07
# AMP iteration with snr=1.2727922061357855 and rho = 0.5
# At iter = 0 we have diff = 1.780553401782515e-06 and overlap=-4.607467520748401e-08
# At iter = 6 AMP converged with overlap=5.161879087368701e-05
# AMP iteration with snr=1.2727922061357855 and rho = 0.5
# At iter = 0 we have diff = 1.7572831562180466e-06 and overlap=-5.205471007708248e-07
# At iter = 6 AMP converged with overlap=-6.401733324983241e-06
# AMP iteration with snr=1.2727922061357855 and rho = 0.5
# At iter = 0 we have diff = 1.771697659239725e-06 and overlap=-1.3211094620188987e-06
# At iter = 5 AMP converged with overlap=-5.874446895738217e-05
# AMP iteration with snr=1.2727922061357855 and rho = 0.5
# At iter = 0 we have diff = 1.7807002933592354e-06 and overlap=-9.054162748223964e-06
# At iter = 6 AMP converged with overlap=1.2652824434201744e-05
# AMP iteration with snr=1.2727922061357855 and rho = 0.5
# At iter = 0 we have diff = 1.877475114925826e-06 and overlap=-5.755678615443637e-06
# At iter = 6 AMP converged with overlap=9.234323311617113e-06
# AMP iteration with snr=1.2727922061357855 and rho = 0.5
# At iter = 0 we have diff = 1.8690762979892527e-06 and overlap=3.322373811735115e-05
# At iter = 6 AMP converged with overlap=5.414749225888705e-05
# AMP iteration with snr=1.2727922061357855 and rho = 0.5
# At iter = 0 we have diff = 1.7515760474741205e-06 and overlap=-2.546046525426452e-06
# At iter = 6 AMP converged with overlap=-4.8664904913945704e-05
# AMP iteration with snr=1.2727922061357855 and rho = 0.5
# At iter = 0 we have diff = 1.8388427469758168e-06 and overlap=2.6665171407702504e-06
# At iter = 6 AMP converged with overlap=1.295371124912962e-06
# AMP iteration with snr=1.2727922061357855 and rho = 0.5
# At iter = 0 we have diff = 1.7234690283903312e-06 and overlap=-1.951868781727288e-06
# At iter = 5 AMP converged with overlap=2.5069240609140156e-05
# AMP iteration with snr=1.2727922061357855 and rho = 0.5
# At iter = 0 we have diff = 1.770629044106644e-06 and overlap=-1.8021654042411344e-05
# At iter = 6 AMP converged with overlap=-2.4070202226282573e-05
# AMP iteration with snr=1.6499158227686108 and rho = 0.5
# At iter = 0 we have diff = 1.838419562607902e-06 and overlap=-1.950410567212965e-05
# At iter = 10 we have diff = 6.372119061042181e-07 and overlap=-0.00030735701211501273
# At iter = 20 we have diff = 6.832890423636672e-06 and overlap=-0.0026177946203177057
# At iter = 30 we have diff = 0.0005399947861515893 and overlap=-0.03036482311145641
# At iter = 40 we have diff = 0.0012517232653256021 and overlap=-0.17808976236527985
# At iter = 50 we have diff = 0.0008276235233839933 and overlap=-0.14612082232710716
# At iter = 60 we have diff = 0.00019204789137567844 and overlap=-0.15766680834425367
# At iter = 70 we have diff = 4.273384837754137e-05 and overlap=-0.16323836978382986
# At iter = 80 we have diff = 1.0426000141323544e-05 and overlap=-0.16242904902304336
# At iter = 90 we have diff = 2.4634630715560456e-06 and overlap=-0.1626653313573121
# At iter = 100 we have diff = 9.012147247769178e-07 and overlap=-0.16292445476753326
# At iter = 110 we have diff = 3.1500672866411237e-07 and overlap=-0.16295772918276466
# At iter = 120 we have diff = 1.0080383984689818e-07 and overlap=-0.16297904772469404
# At iter = 121 AMP converged with overlap=-0.16298557328466495
# AMP iteration with snr=1.6499158227686108 and rho = 0.5
# At iter = 0 we have diff = 1.7124823029484102e-06 and overlap=2.9412538776490394e-05
# At iter = 10 we have diff = 4.870968130705929e-07 and overlap=0.00018139514551522264
# At iter = 20 we have diff = 1.5062359833213445e-06 and overlap=-0.00020220861562243503
# At iter = 30 we have diff = 1.6202957846359098e-05 and overlap=-0.003406647947201744
# At iter = 40 we have diff = 0.001195382636217491 and overlap=-0.050111373896087885
# At iter = 50 we have diff = 0.0020611548476835726 and overlap=-0.17492117325327264
# At iter = 60 we have diff = 0.0010015970461139366 and overlap=-0.14505407130877046
# At iter = 70 we have diff = 0.00039817766800927343 and overlap=-0.14826491386062093
# At iter = 80 we have diff = 0.000122706842051571 and overlap=-0.150272833407787
# At iter = 90 we have diff = 5.1575795171227115e-05 and overlap=-0.1474436800041619
# At iter = 100 we have diff = 2.5078856979895867e-05 and overlap=-0.14953454054854187
# At iter = 110 we have diff = 1.4299827664274132e-05 and overlap=-0.14838309310599815
# At iter = 120 we have diff = 1.1524326928626786e-05 and overlap=-0.14874805676169217
# At iter = 130 we have diff = 7.686902654356253e-06 and overlap=-0.1486957653355592
# At iter = 140 we have diff = 5.798595224088812e-06 and overlap=-0.14864604505440576
# At iter = 150 we have diff = 4.2060873224038024e-06 and overlap=-0.14872964142187714
# At iter = 160 we have diff = 2.7768398546539626e-06 and overlap=-0.14872341733863498
# At iter = 170 we have diff = 1.6723795468788267e-06 and overlap=-0.14877612679919627
# At iter = 180 we have diff = 9.290588185608176e-07 and overlap=-0.14879638579527132
# At iter = 190 we have diff = 5.1043882982145e-07 and overlap=-0.14881374821562843
# At iter = 200 we have diff = 2.902524941316978e-07 and overlap=-0.14882220032532575
# At iter = 210 we have diff = 1.7199722134461544e-07 and overlap=-0.1488213678219784
# At iter = 216 AMP converged with overlap=-0.1487897015585644
# AMP iteration with snr=1.6499158227686108 and rho = 0.5
# At iter = 0 we have diff = 1.8302933829558606e-06 and overlap=-1.3338229469402325e-05
# At iter = 10 we have diff = 6.69764741843035e-07 and overlap=-0.0005301460111980795
# At iter = 20 we have diff = 2.5327281999985846e-05 and overlap=-0.006407689815996125
# At iter = 30 we have diff = 0.0031775989173958904 and overlap=-0.08078846458797398
# At iter = 40 we have diff = 0.0026453333688910585 and overlap=-0.13569166490748027
# At iter = 50 we have diff = 0.0005541800107578762 and overlap=-0.15225845319085146
# At iter = 60 we have diff = 0.00020427611146864506 and overlap=-0.14057428686641668
# At iter = 70 we have diff = 6.051852933057978e-05 and overlap=-0.14288052834212447
# At iter = 80 we have diff = 2.5078675761750637e-05 and overlap=-0.14326340636683146
# At iter = 90 we have diff = 8.507706934842511e-06 and overlap=-0.14313401249040666
# At iter = 100 we have diff = 2.8222732391873523e-06 and overlap=-0.14318494375213295
# At iter = 110 we have diff = 1.4614485356346476e-06 and overlap=-0.14290660661624843
# At iter = 120 we have diff = 6.438078406403935e-07 and overlap=-0.1428924417855881
# At iter = 130 we have diff = 3.5723395790531854e-07 and overlap=-0.14301635609361368
# At iter = 140 we have diff = 1.2311746974270314e-07 and overlap=-0.14303691640616978
# At iter = 142 AMP converged with overlap=-0.14300863003501377
# AMP iteration with snr=1.6499158227686108 and rho = 0.5
# At iter = 0 we have diff = 1.804690598304064e-06 and overlap=1.1262796146718421e-05
# At iter = 10 we have diff = 5.027075193862326e-07 and overlap=0.00015306182093920045
# At iter = 20 we have diff = 1.5870525139154978e-06 and overlap=5.852083081358823e-05
# At iter = 30 we have diff = 1.2059011837268014e-05 and overlap=-0.001737594649037717
# At iter = 40 we have diff = 7.515917857033929e-05 and overlap=-0.007480288297880093
# At iter = 50 we have diff = 0.0004105253363391715 and overlap=-0.006599434667832538
# At iter = 60 we have diff = 0.001870281173109405 and overlap=-0.0211724127371435
# At iter = 70 we have diff = 0.003124902006004125 and overlap=0.0004000794874540188
# At iter = 80 we have diff = 0.005303135940967917 and overlap=-0.013726768257081006
# At iter = 90 we have diff = 0.004847752567173177 and overlap=0.013274325503474101
# At iter = 100 we have diff = 0.0033998136462703053 and overlap=0.018207929576817983
# At iter = 110 we have diff = 0.0034775552858371957 and overlap=0.01948809129231977
# At iter = 120 we have diff = 0.004633689381040996 and overlap=-0.006302114316723536
# At iter = 130 we have diff = 0.004818557447993974 and overlap=-0.037522157786820484
# At iter = 140 we have diff = 0.00233457007202441 and overlap=-0.028303923850761848
# At iter = 150 we have diff = 0.005886355433047358 and overlap=0.020095488870843788
# At iter = 160 we have diff = 0.004656146128025378 and overlap=0.011270819686797925
# At iter = 170 we have diff = 0.004633367173762383 and overlap=0.024985548048750538
# At iter = 180 we have diff = 0.004692052948728245 and overlap=0.006912808865529413
# At iter = 190 we have diff = 0.0050006156985749695 and overlap=-0.02720347627272176
# At iter = 200 we have diff = 0.00545460054457458 and overlap=-0.006867839878537785
# At iter = 210 we have diff = 0.003089453137557304 and overlap=0.009490408857266878
# At iter = 220 we have diff = 0.0032436734650419467 and overlap=-0.007725702497200357
# At iter = 230 we have diff = 0.003865809742874082 and overlap=-0.03106668200268628
# At iter = 240 we have diff = 0.004961078424731631 and overlap=-0.005584529285052637
# At iter = 250 we have diff = 0.0036499034850435257 and overlap=0.04972978455237118
# At iter = 260 we have diff = 0.0032169371248173314 and overlap=0.04469205651121328
# At iter = 270 we have diff = 0.004130626923860227 and overlap=-0.033181146480249876
# At iter = 280 we have diff = 0.0057883774892566655 and overlap=-0.041745173692545365
# At iter = 290 we have diff = 0.004673852755240256 and overlap=-0.016885273024960155
# At iter = 300 we have diff = 0.004323613055115114 and overlap=-0.004840900272108005
# At iter = 310 we have diff = 0.0036588507146978226 and overlap=-0.021810907425252508
# At iter = 320 we have diff = 0.0048647257930296735 and overlap=-0.032898768324876426
# At iter = 330 we have diff = 0.005675430408171512 and overlap=0.01916196897311521
# At iter = 340 we have diff = 0.005867673290844481 and overlap=0.037169817615943346
# At iter = 350 we have diff = 0.004016575083009499 and overlap=0.01483832038814153
# At iter = 360 we have diff = 0.004571887629632068 and overlap=0.0016054445497368528
# At iter = 370 we have diff = 0.006085081114294746 and overlap=-0.004792387109836547
# At iter = 380 we have diff = 0.006958367272929383 and overlap=0.017775752286713895
# At iter = 390 we have diff = 0.0071001790575272086 and overlap=-0.01614811402039701
# At iter = 400 we have diff = 0.006521957598150283 and overlap=-0.022231909191121058
# At iter = 410 we have diff = 0.005710987192298339 and overlap=-0.005211379266175317
# At iter = 420 we have diff = 0.004846161673422689 and overlap=-0.02366253440943166
# At iter = 430 we have diff = 0.005005715256843541 and overlap=-0.020646348340194725
# At iter = 440 we have diff = 0.005402098709377495 and overlap=-0.027838925918714088
# At iter = 450 we have diff = 0.006966110789644649 and overlap=0.01887721412738847
# At iter = 460 we have diff = 0.006203811306217857 and overlap=0.014312752931126884
# At iter = 470 we have diff = 0.008031235330159169 and overlap=-0.009950515330525728
# At iter = 480 we have diff = 0.003937970669830748 and overlap=0.017264641056088905
# At iter = 490 we have diff = 0.003535559408684499 and overlap=0.04856817034311883
# AMP iteration with snr=1.6499158227686108 and rho = 0.5
# At iter = 0 we have diff = 1.786478606661629e-06 and overlap=-6.755200518253957e-07
# At iter = 10 we have diff = 5.675150054378657e-07 and overlap=-0.00017439784377818279
# At iter = 20 we have diff = 2.794755628632745e-05 and overlap=-0.0071753513306700885
# At iter = 30 we have diff = 0.027452749969816632 and overlap=-0.2688818057583463
# At iter = 40 we have diff = 0.0002004949191318042 and overlap=-0.31076714580629744
# At iter = 50 we have diff = 1.448302977397589e-06 and overlap=-0.31977677653347525
# At iter = 58 AMP converged with overlap=-0.3206445976282979
# AMP iteration with snr=1.6499158227686108 and rho = 0.5
# At iter = 0 we have diff = 1.6474389056612397e-06 and overlap=9.543653442217275e-06
# At iter = 10 we have diff = 5.238960562728209e-07 and overlap=0.00032827350295589597
# At iter = 20 we have diff = 4.655459613203332e-06 and overlap=0.003187755584237504
# At iter = 30 we have diff = 0.00014279937437841926 and overlap=0.021013476245089324
# At iter = 40 we have diff = 0.0036964215129994607 and overlap=0.12141767419919174
# At iter = 50 we have diff = 0.001504631543755009 and overlap=0.10772053829906002
# At iter = 60 we have diff = 0.0005904969726089804 and overlap=0.11540187860937641
# At iter = 70 we have diff = 0.00024376756909726008 and overlap=0.1106094212429866
# At iter = 80 we have diff = 0.00016232077724041198 and overlap=0.11635140056134259
# At iter = 90 we have diff = 0.0001713231582257065 and overlap=0.10824874832982334
# At iter = 100 we have diff = 0.00015628407066299924 and overlap=0.1104532982678318
# At iter = 110 we have diff = 0.0001353697474384005 and overlap=0.10733863414716803
# At iter = 120 we have diff = 0.00016270874064590917 and overlap=0.11002749432251016
# At iter = 130 we have diff = 0.00016331944607086914 and overlap=0.11024328344882937
# At iter = 140 we have diff = 0.00016338201382063534 and overlap=0.10803703335979742
# At iter = 150 we have diff = 0.00016261365663999515 and overlap=0.10837755633906512
# At iter = 160 we have diff = 0.00012194870986688105 and overlap=0.10759545996504463
# At iter = 170 we have diff = 0.00011300107405367343 and overlap=0.10904914680157779
# At iter = 180 we have diff = 0.00011818169273453899 and overlap=0.11016595290913901
# At iter = 190 we have diff = 0.00013527902890132277 and overlap=0.11034778956995094
# At iter = 200 we have diff = 0.00023903871529246497 and overlap=0.11004892157270076
# At iter = 210 we have diff = 0.0003473682967659491 and overlap=0.10875513714181025
# At iter = 220 we have diff = 0.0003948595100342388 and overlap=0.10867191112211617
# At iter = 230 we have diff = 0.0004111669729094251 and overlap=0.10923193232204124
# At iter = 240 we have diff = 0.00037417998901915497 and overlap=0.10950703259348177
# At iter = 250 we have diff = 0.0003027017520905247 and overlap=0.10893080092448429
# At iter = 260 we have diff = 0.0002747316759634092 and overlap=0.10746697949601246
# At iter = 270 we have diff = 0.00030870829291234514 and overlap=0.10680836835262672
# At iter = 280 we have diff = 0.0004307749797064344 and overlap=0.1073549676670321
# At iter = 290 we have diff = 0.0006113460909901867 and overlap=0.10874920742442462
# At iter = 300 we have diff = 0.0007202272943965479 and overlap=0.11020660221740144
# At iter = 310 we have diff = 0.0007077388999417467 and overlap=0.11099712747025631
# At iter = 320 we have diff = 0.0006321834979375223 and overlap=0.11147508007008662
# At iter = 330 we have diff = 0.0005270007307619004 and overlap=0.11217259624193986
# At iter = 340 we have diff = 0.00043946276188370505 and overlap=0.11323063418164633
# At iter = 350 we have diff = 0.0004329447671193275 and overlap=0.11413228484160774
# At iter = 360 we have diff = 0.000526633966372223 and overlap=0.11422946869556082
# At iter = 370 we have diff = 0.0006816528674146373 and overlap=0.11345864273470233
# At iter = 380 we have diff = 0.0008003339595734407 and overlap=0.11225275566415789
# At iter = 390 we have diff = 0.0008047664404589815 and overlap=0.11119249670755996
# At iter = 400 we have diff = 0.0007067461707653132 and overlap=0.1104931719153552
# At iter = 410 we have diff = 0.0005726103712377496 and overlap=0.10996608332756537
# At iter = 420 we have diff = 0.00047438178562512155 and overlap=0.10941426043324469
# At iter = 430 we have diff = 0.0004633484197242409 and overlap=0.10891581136332436
# At iter = 440 we have diff = 0.0005424627352148114 and overlap=0.10879871170137446
# At iter = 450 we have diff = 0.0006691703900684108 and overlap=0.10930935273715657
# At iter = 460 we have diff = 0.0007747133503173504 and overlap=0.11037761846669909
# At iter = 470 we have diff = 0.0007882928312353177 and overlap=0.11165720662014442
# At iter = 480 we have diff = 0.0007008797087178689 and overlap=0.11275954076084957
# At iter = 490 we have diff = 0.0005794705515275202 and overlap=0.11351470092918019
# AMP iteration with snr=1.6499158227686108 and rho = 0.5
# At iter = 0 we have diff = 1.7977548980387577e-06 and overlap=-1.5657232552183327e-05
# At iter = 10 we have diff = 6.373812899403152e-07 and overlap=-0.00016698987982951202
# At iter = 20 we have diff = 3.352070635220715e-06 and overlap=-0.0017319196101385809
# At iter = 30 we have diff = 0.00019412351629420648 and overlap=-0.02174769509123156
# At iter = 40 we have diff = 0.004520263515820254 and overlap=-0.17136001275921844
# At iter = 50 we have diff = 0.0006037111695134769 and overlap=-0.12366018026795146
# At iter = 60 we have diff = 0.0003300431311546915 and overlap=-0.1489227224015774
# At iter = 70 we have diff = 0.00017194485070692287 and overlap=-0.1412973316916487
# At iter = 80 we have diff = 6.764635781980628e-05 and overlap=-0.1432369430884266
# At iter = 90 we have diff = 2.7493856409397347e-05 and overlap=-0.14302049500606354
# At iter = 100 we have diff = 8.811667555462765e-06 and overlap=-0.14055801913945914
# At iter = 110 we have diff = 4.8467529226037685e-06 and overlap=-0.14235355219117218
# At iter = 120 we have diff = 3.214955123462639e-06 and overlap=-0.14241856625461793
# At iter = 130 we have diff = 2.5115991619367583e-06 and overlap=-0.1417485368188122
# At iter = 140 we have diff = 1.6571498147646603e-06 and overlap=-0.14180265367279188
# At iter = 150 we have diff = 1.0109910861916488e-06 and overlap=-0.14218324038378238
# At iter = 160 we have diff = 1.380496608067584e-06 and overlap=-0.14191401149572372
# At iter = 170 we have diff = 1.599621923981581e-06 and overlap=-0.1417578138865812
# At iter = 180 we have diff = 1.0807349179176933e-06 and overlap=-0.14184432522423376
# At iter = 190 we have diff = 6.423962011316704e-07 and overlap=-0.14187681181676678
# At iter = 200 we have diff = 8.155774063629406e-07 and overlap=-0.1418611887195922
# At iter = 210 we have diff = 1.0413193473110323e-06 and overlap=-0.14190144574836905
# At iter = 220 we have diff = 8.00226697261782e-07 and overlap=-0.14197398544331155
# At iter = 230 we have diff = 4.501085560990113e-07 and overlap=-0.14195963279430987
# At iter = 240 we have diff = 4.910107826031466e-07 and overlap=-0.14191027406277182
# At iter = 250 we have diff = 6.97888008650032e-07 and overlap=-0.14188143532534417
# At iter = 260 we have diff = 6.074148886623324e-07 and overlap=-0.14185800578144783
# At iter = 270 we have diff = 3.4251218554493727e-07 and overlap=-0.14184562912839901
# At iter = 280 we have diff = 3.037810128866351e-07 and overlap=-0.14186488629187724
# At iter = 290 we have diff = 4.504888468544485e-07 and overlap=-0.14190330678752722
# At iter = 300 we have diff = 4.43825219284888e-07 and overlap=-0.14193047525151897
# At iter = 310 we have diff = 2.657615503648399e-07 and overlap=-0.1419367320660064
# At iter = 320 we have diff = 1.9384752846126035e-07 and overlap=-0.1419245341262514
# At iter = 330 we have diff = 2.8519310595022614e-07 and overlap=-0.14189906415774015
# At iter = 340 we have diff = 3.1730780006955976e-07 and overlap=-0.1418728655591866
# At iter = 350 we have diff = 2.0779352587732246e-07 and overlap=-0.141861110711171
# At iter = 360 we have diff = 1.2953697613613894e-07 and overlap=-0.1418687772527173
# At iter = 370 we have diff = 1.7690291371848398e-07 and overlap=-0.1418890968306513
# At iter = 380 we have diff = 2.2013660768881612e-07 and overlap=-0.14191080430460687
# At iter = 390 we have diff = 1.6092359606464265e-07 and overlap=-0.1419233594668429
# At iter = 396 AMP converged with overlap=-0.14187563841846176
# AMP iteration with snr=1.6499158227686108 and rho = 0.5
# At iter = 0 we have diff = 1.837890274461938e-06 and overlap=-1.8974409695858736e-05
# At iter = 10 we have diff = 6.727320756069057e-07 and overlap=-9.164214842995503e-05
# At iter = 20 we have diff = 8.3599521291556e-06 and overlap=0.001622188239231966
# At iter = 30 we have diff = 0.0006419227538752524 and overlap=0.026677595296144038
# At iter = 40 we have diff = 0.0009053865284364017 and overlap=0.12442112433868271
# At iter = 50 we have diff = 0.0005652890935216198 and overlap=0.09145308586021907
# At iter = 60 we have diff = 0.0002564070124293984 and overlap=0.10927209029827532
# At iter = 70 we have diff = 0.0001507434203623232 and overlap=0.0991069653121659
# At iter = 80 we have diff = 7.420166945364878e-05 and overlap=0.09713053986656936
# At iter = 90 we have diff = 3.249084264432225e-05 and overlap=0.09677999909135869
# At iter = 100 we have diff = 1.995799360241322e-05 and overlap=0.09559807943919278
# At iter = 110 we have diff = 1.387043951194553e-05 and overlap=0.09798210521651614
# At iter = 120 we have diff = 8.110797885968969e-06 and overlap=0.09801206163734441
# At iter = 130 we have diff = 5.9611589915879414e-06 and overlap=0.09683544425804422
# At iter = 140 we have diff = 3.9996758390395515e-06 and overlap=0.09623453403605584
# At iter = 150 we have diff = 2.544003970141684e-06 and overlap=0.09636533304102685
# At iter = 160 we have diff = 2.9956657712494465e-06 and overlap=0.09715494639522167
# At iter = 170 we have diff = 1.473104709539381e-06 and overlap=0.09697528115876289
# At iter = 180 we have diff = 1.946746969112667e-06 and overlap=0.09709792721489956
# At iter = 190 we have diff = 8.416100733720846e-07 and overlap=0.09660935146253453
# At iter = 200 we have diff = 1.3528752381813633e-06 and overlap=0.0965147904561079
# At iter = 210 we have diff = 5.817231227536131e-07 and overlap=0.09688838127977491
# At iter = 220 we have diff = 9.348192961332383e-07 and overlap=0.0969649839908827
# At iter = 230 we have diff = 4.7117013657054564e-07 and overlap=0.09681860964271002
# At iter = 240 we have diff = 5.515604122339448e-07 and overlap=0.096667750532441
# At iter = 250 we have diff = 3.9473648513361257e-07 and overlap=0.09684140928441176
# At iter = 260 we have diff = 3.3234195493354235e-07 and overlap=0.09681098054791205
# At iter = 270 we have diff = 3.1725584699984694e-07 and overlap=0.09677119403503645
# At iter = 280 we have diff = 1.9993956190691325e-07 and overlap=0.09680870229057754
# At iter = 290 we have diff = 2.5198761937082463e-07 and overlap=0.09680380546354851
# At iter = 300 we have diff = 1.1810206727354809e-07 and overlap=0.09681702120203577
# At iter = 307 AMP converged with overlap=0.09673822634474487
# AMP iteration with snr=1.6499158227686108 and rho = 0.5
# At iter = 0 we have diff = 1.7952910563547875e-06 and overlap=-2.2118735206240984e-05
# At iter = 10 we have diff = 8.250545154226762e-07 and overlap=0.0006487806409140778
# At iter = 20 we have diff = 3.434833258232019e-05 and overlap=0.008392875223996493
# At iter = 30 we have diff = 0.0031427916617588958 and overlap=0.08280829339533796
# At iter = 40 we have diff = 0.002284943666782023 and overlap=0.11648887615198396
# At iter = 50 we have diff = 0.0006338860054095358 and overlap=0.11921738034077274
# At iter = 60 we have diff = 0.00015051171217552725 and overlap=0.10812383775653268
# At iter = 70 we have diff = 6.411327934719116e-05 and overlap=0.11286792972354787
# At iter = 80 we have diff = 3.2021328180890867e-05 and overlap=0.1112421071860766
# At iter = 90 we have diff = 1.578571966152227e-05 and overlap=0.11231412636061977
# At iter = 100 we have diff = 5.142300222042845e-06 and overlap=0.11251858051118978
# At iter = 110 we have diff = 2.106100678003186e-06 and overlap=0.11197148838402296
# At iter = 120 we have diff = 1.2034594349748574e-06 and overlap=0.11217282213898053
# At iter = 130 we have diff = 6.830641131288115e-07 and overlap=0.11208878666963869
# At iter = 140 we have diff = 3.64120466216093e-07 and overlap=0.11211701331980749
# At iter = 150 we have diff = 2.047510338569901e-07 and overlap=0.11214003420764672
# At iter = 157 AMP converged with overlap=0.11209267497214913
# AMP iteration with snr=1.6499158227686108 and rho = 0.5
# At iter = 0 we have diff = 1.8680026486133052e-06 and overlap=5.156878603286843e-06
# At iter = 10 we have diff = 8.803350823720103e-07 and overlap=0.00038082901003048627
# At iter = 20 we have diff = 1.112739399506657e-05 and overlap=0.002768888541340366
# At iter = 30 we have diff = 0.000332464316471122 and overlap=0.023033182487555884
# At iter = 40 we have diff = 0.0021113309192593833 and overlap=0.11455220451545164
# At iter = 50 we have diff = 0.0009060113641416435 and overlap=0.08296116324598582
# At iter = 60 we have diff = 0.00033116982644380323 and overlap=0.06874494110752627
# At iter = 70 we have diff = 0.0003156587845009152 and overlap=0.061921216876228036
# At iter = 80 we have diff = 0.0006373849156204712 and overlap=0.019688781953430632
# At iter = 90 we have diff = 0.00849944965312313 and overlap=-0.0716834583145586
# At iter = 100 we have diff = 0.0028716049776531787 and overlap=-0.09564554409020745
# At iter = 110 we have diff = 0.00044798190106142195 and overlap=-0.09180729607217171
# At iter = 120 we have diff = 0.00032953602796189084 and overlap=-0.08634708890426214
# At iter = 130 we have diff = 0.0001906677921927001 and overlap=-0.06179066235851393
# At iter = 140 we have diff = 0.000245917493268619 and overlap=-0.03970215479597407
# At iter = 150 we have diff = 0.0019031874707278508 and overlap=-0.0028578992053807477
# At iter = 160 we have diff = 0.003319331314977336 and overlap=0.11460961472641591
# At iter = 170 we have diff = 0.0008269056717985944 and overlap=0.0879695206994084
# At iter = 180 we have diff = 0.00048712785039583525 and overlap=0.09574436294111317
# At iter = 190 we have diff = 0.00033878713512884047 and overlap=0.06793081102413098
# At iter = 200 we have diff = 0.00033640516060994994 and overlap=0.05380426265412392
# At iter = 210 we have diff = 0.0007182814030934335 and overlap=0.027025584589329115
# At iter = 220 we have diff = 0.00992489169119613 and overlap=-0.090819437426862
# At iter = 230 we have diff = 0.0021308330496577223 and overlap=-0.07550581935655991
# At iter = 240 we have diff = 0.0007723911566685836 and overlap=-0.09459108603394105
# At iter = 250 we have diff = 0.00048667859721409826 and overlap=-0.08293227654321217
# At iter = 260 we have diff = 0.00029926446681183 and overlap=-0.05638659135693395
# At iter = 270 we have diff = 0.00042237391509216456 and overlap=-0.03398561331034155
# At iter = 280 we have diff = 0.00443904437644428 and overlap=0.035048455132212004
# At iter = 290 we have diff = 0.005041363464584682 and overlap=0.09878507036297147
# At iter = 300 we have diff = 0.0008762319504494549 and overlap=0.089778540416773
# At iter = 310 we have diff = 0.0006494961469955657 and overlap=0.09086554754357257
# At iter = 320 we have diff = 0.0003123883842772796 and overlap=0.05982004215663255
# At iter = 330 we have diff = 0.00038971815449737366 and overlap=0.03453299003485718
# At iter = 340 we have diff = 0.0030323406043443824 and overlap=-0.02418455908307015
# At iter = 350 we have diff = 0.004243788047874117 and overlap=-0.1222913121314328
# At iter = 360 we have diff = 0.0009309715840206461 and overlap=-0.08570514819884192
# At iter = 370 we have diff = 0.0005525287219635982 and overlap=-0.09549193540921905
# At iter = 380 we have diff = 0.00033559710054523027 and overlap=-0.07056257543644509
# At iter = 390 we have diff = 0.00024090363731997644 and overlap=-0.05280602882518205
# At iter = 400 we have diff = 0.0005867404211865162 and overlap=-0.02559234552547845
# At iter = 410 we have diff = 0.010337977949287785 and overlap=0.07740985322512552
# At iter = 420 we have diff = 0.002157102281238902 and overlap=0.08401791249380625
# At iter = 430 we have diff = 0.0005448253338394408 and overlap=0.10180753784892915
# At iter = 440 we have diff = 0.00041155864198017135 and overlap=0.0812009553784441
# At iter = 450 we have diff = 0.0002726941672476069 and overlap=0.055324721263378195
# At iter = 460 we have diff = 0.00030952122963328374 and overlap=0.04307386414528194
# At iter = 470 we have diff = 0.002854818697306594 and overlap=-0.012176352483941404
# At iter = 480 we have diff = 0.005240288882518946 and overlap=-0.10418215161241351
# At iter = 490 we have diff = 0.0009930446698886413 and overlap=-0.08962912465334318
# AMP iteration with snr=2.027039439401436 and rho = 0.5
# At iter = 0 we have diff = 1.7072762482884854e-06 and overlap=-2.0856607090872832e-06
# At iter = 10 we have diff = 9.899783519396244e-05 and overlap=0.00867428406336944
# At iter = 20 we have diff = 0.006870659615570469 and overlap=0.3553813735702438
# At iter = 30 we have diff = 0.0001990614245305156 and overlap=0.3391364971279852
# At iter = 40 we have diff = 3.794328775955594e-06 and overlap=0.3408439580132421
# At iter = 50 we have diff = 8.251694639923117e-08 and overlap=0.341717587351344
# At iter = 50 AMP converged with overlap=0.341717587351344
# AMP iteration with snr=2.027039439401436 and rho = 0.5
# At iter = 0 we have diff = 1.7489996106580334e-06 and overlap=4.7035435971145374e-05
# At iter = 10 we have diff = 0.00018253351169729903 and overlap=0.013671065131518848
# At iter = 20 we have diff = 0.005012453278352428 and overlap=0.3584645553519187
# At iter = 30 we have diff = 1.5557386838042163e-05 and overlap=0.37140024631434393
# At iter = 40 we have diff = 7.130980153554414e-07 and overlap=0.3740699711009572
# At iter = 49 AMP converged with overlap=0.37480305792688007
# AMP iteration with snr=2.027039439401436 and rho = 0.5
# At iter = 0 we have diff = 1.6730107058960686e-06 and overlap=-6.019780340904965e-06
# At iter = 10 we have diff = 0.00011376717298299979 and overlap=0.011255466852962057
# At iter = 20 we have diff = 0.005910824435145323 and overlap=0.3412598391153473
# At iter = 30 we have diff = 0.0001145769905047065 and overlap=0.33233859604514887
# At iter = 40 we have diff = 2.9225955367900984e-06 and overlap=0.33262178377991997
# At iter = 49 AMP converged with overlap=0.3331526731216066
# AMP iteration with snr=2.027039439401436 and rho = 0.5
# At iter = 0 we have diff = 1.7735130264513437e-06 and overlap=3.371807521667173e-05
# At iter = 10 we have diff = 0.00016614887963444324 and overlap=0.01353325004777341
# At iter = 20 we have diff = 0.0073070585982109 and overlap=0.34704023682138163
# At iter = 30 we have diff = 0.00016785553604359025 and overlap=0.33974768524460974
# At iter = 40 we have diff = 7.598903123048651e-06 and overlap=0.33829530268603775
# At iter = 50 we have diff = 2.3490336588156494e-07 and overlap=0.33828092181569197
# At iter = 54 AMP converged with overlap=0.33830336292808
# AMP iteration with snr=2.027039439401436 and rho = 0.5
# At iter = 0 we have diff = 1.7271906160300892e-06 and overlap=6.1774981495241e-05
# At iter = 10 we have diff = 0.00017730458545818688 and overlap=0.015251806016655187
# At iter = 20 we have diff = 0.005242585318189922 and overlap=0.3690889226709255
# At iter = 30 we have diff = 1.7485158976506587e-05 and overlap=0.37644495916017595
# At iter = 40 we have diff = 3.6791848361342786e-07 and overlap=0.37837732226247295
# At iter = 45 AMP converged with overlap=0.37875788543000727
# AMP iteration with snr=2.027039439401436 and rho = 0.5
# At iter = 0 we have diff = 1.6556357707895861e-06 and overlap=2.1606798371017452e-05
# At iter = 10 we have diff = 6.300010619773839e-05 and overlap=0.008009225619793902
# At iter = 20 we have diff = 0.00525577702212672 and overlap=0.3539159744506951
# At iter = 30 we have diff = 0.0001600836661990212 and overlap=0.3308174616809541
# At iter = 40 we have diff = 3.1941771416730785e-06 and overlap=0.33108777600530553
# At iter = 50 we have diff = 7.716660138883229e-08 and overlap=0.3318188877834074
# At iter = 50 AMP converged with overlap=0.3318188877834074
# AMP iteration with snr=2.027039439401436 and rho = 0.5
# At iter = 0 we have diff = 1.7677433355492143e-06 and overlap=-7.626734761307443e-07
# At iter = 10 we have diff = 0.00027323856315063125 and overlap=0.01613481496528147
# At iter = 20 we have diff = 0.007738300100334491 and overlap=0.3142152707775291
# At iter = 30 we have diff = 0.00022223828450626467 and overlap=0.31522678356704353
# At iter = 40 we have diff = 7.512443226949143e-06 and overlap=0.3139893798734686
# At iter = 50 we have diff = 3.2322047665428365e-07 and overlap=0.3144462956510734
# At iter = 53 AMP converged with overlap=0.314477816411047
# AMP iteration with snr=2.027039439401436 and rho = 0.5
# At iter = 0 we have diff = 1.7807456824998334e-06 and overlap=2.951211748851638e-05
# At iter = 10 we have diff = 0.00011556212749386268 and overlap=0.012141770219283955
# At iter = 20 we have diff = 0.0054458084448227966 and overlap=0.40056410347919996
# At iter = 30 we have diff = 2.150582520713983e-05 and overlap=0.39736143956399195
# At iter = 40 we have diff = 3.784515950592742e-07 and overlap=0.3993594862566938
# At iter = 45 AMP converged with overlap=0.3997104741073033
# AMP iteration with snr=2.027039439401436 and rho = 0.5
# At iter = 0 we have diff = 1.7952654392065052e-06 and overlap=3.242724534028678e-05
# At iter = 10 we have diff = 0.00014612540247940014 and overlap=0.009856164657633738
# At iter = 20 we have diff = 0.006604189372062809 and overlap=0.36353647403571915
# At iter = 30 we have diff = 2.3694751245979345e-05 and overlap=0.36102397660424207
# At iter = 40 we have diff = 2.3699754365935697e-07 and overlap=0.36228773539282044
# At iter = 42 AMP converged with overlap=0.36238940432425804
# AMP iteration with snr=2.027039439401436 and rho = 0.5
# At iter = 0 we have diff = 1.6999697454343196e-06 and overlap=-4.181887405649785e-05
# At iter = 10 we have diff = 0.0001136582320678308 and overlap=-0.00723290337152109
# At iter = 20 we have diff = 0.005872946346998828 and overlap=-0.26572720740339173
# At iter = 30 we have diff = 0.00030028590656899545 and overlap=-0.26294895422273334
# At iter = 40 we have diff = 8.50879981824165e-06 and overlap=-0.26294556760779836
# At iter = 50 we have diff = 2.688037727247902e-07 and overlap=-0.26348238352433123
# At iter = 53 AMP converged with overlap=-0.26358763108730127
# AMP iteration with snr=2.4041630560342617 and rho = 0.5
# At iter = 0 we have diff = 1.6668034937814782e-06 and overlap=2.313088452418036e-05
# At iter = 10 we have diff = 0.009880208602016674 and overlap=0.09748388210846885
# At iter = 20 we have diff = 0.0003471364294285204 and overlap=0.44149971613076333
# At iter = 30 we have diff = 2.127242334926112e-06 and overlap=0.4544332840216986
# At iter = 40 we have diff = 1.1821702560024772e-07 and overlap=0.45528341202067835
# At iter = 41 AMP converged with overlap=0.45530016599426854
# AMP iteration with snr=2.4041630560342617 and rho = 0.5
# At iter = 0 we have diff = 1.6682191380980616e-06 and overlap=4.295717843387921e-05
# At iter = 10 we have diff = 0.01566021493661694 and overlap=0.12341449802233864
# At iter = 20 we have diff = 0.0004238409329613836 and overlap=0.39352219426127827
# At iter = 30 we have diff = 3.124242629353624e-06 and overlap=0.40653305042144894
# At iter = 40 we have diff = 2.7553576031419037e-07 and overlap=0.40757048857928235
# At iter = 45 AMP converged with overlap=0.40767480287966235
# AMP iteration with snr=2.4041630560342617 and rho = 0.5
# At iter = 0 we have diff = 1.8466052795982492e-06 and overlap=8.92078678182315e-05
# At iter = 10 we have diff = 0.04404812073842031 and overlap=0.23888548051889666
# At iter = 20 we have diff = 0.0002571478833658168 and overlap=0.44974567224455686
# At iter = 30 we have diff = 8.568392901681147e-07 and overlap=0.4570846024977969
# At iter = 37 AMP converged with overlap=0.45757680204159257
# AMP iteration with snr=2.4041630560342617 and rho = 0.5
# At iter = 0 we have diff = 1.819386478376333e-06 and overlap=6.162160005404255e-07
# At iter = 10 we have diff = 0.0023316720868058216 and overlap=-0.02679684834536994
# At iter = 20 we have diff = 0.012477173862200569 and overlap=-0.276354819944122
# At iter = 30 we have diff = 0.00032866644969860987 and overlap=-0.353741826916372
# At iter = 40 we have diff = 8.140756372312524e-06 and overlap=-0.36013714686819687
# At iter = 50 we have diff = 5.692607564875248e-07 and overlap=-0.36145957069356116
# At iter = 59 AMP converged with overlap=-0.36180250866097613
# AMP iteration with snr=2.4041630560342617 and rho = 0.5
# At iter = 0 we have diff = 1.7779195760086497e-06 and overlap=-3.924152551505907e-05
# At iter = 10 we have diff = 0.00508544724510745 and overlap=-0.06818484665683762
# At iter = 20 we have diff = 0.00041271363484987123 and overlap=-0.41759780630920174
# At iter = 30 we have diff = 1.5829548923315556e-06 and overlap=-0.4356444221033299
# At iter = 38 AMP converged with overlap=-0.4370097512296327
# AMP iteration with snr=2.4041630560342617 and rho = 0.5
# At iter = 0 we have diff = 1.7612888542823305e-06 and overlap=-2.891890568721877e-06
# At iter = 10 we have diff = 0.006851295921045414 and overlap=-0.07993846640316962
# At iter = 20 we have diff = 0.002080288209522374 and overlap=-0.2997598907439225
# At iter = 30 we have diff = 0.0001708661258832946 and overlap=-0.3293354366259748
# At iter = 40 we have diff = 8.551905089909358e-06 and overlap=-0.33210283961141174
# At iter = 50 we have diff = 4.921374936272772e-07 and overlap=-0.33220014888274574
# At iter = 56 AMP converged with overlap=-0.33225400896428314
# AMP iteration with snr=2.4041630560342617 and rho = 0.5
# At iter = 0 we have diff = 1.7748485703005865e-06 and overlap=-1.943527304350429e-06
# At iter = 10 we have diff = 0.012754082342212016 and overlap=0.11075243095641395
# At iter = 20 we have diff = 0.0002952221889695453 and overlap=0.42793720752415243
# At iter = 30 we have diff = 1.733578625385362e-06 and overlap=0.43936420203252136
# At iter = 40 we have diff = 1.0017284798052318e-07 and overlap=0.4402146930681007
# At iter = 41 AMP converged with overlap=0.4402366292718412
# AMP iteration with snr=2.4041630560342617 and rho = 0.5
# At iter = 0 we have diff = 1.6911212479121214e-06 and overlap=2.350940734410996e-05
# At iter = 10 we have diff = 0.02296152899696203 and overlap=0.1547532537827888
# At iter = 20 we have diff = 0.0009782561151943719 and overlap=0.3815742417956874
# At iter = 30 we have diff = 8.03621087786967e-06 and overlap=0.39995130609811186
# At iter = 40 we have diff = 2.197950095447613e-07 and overlap=0.4020057395296184
# At iter = 44 AMP converged with overlap=0.40221278155692347
# AMP iteration with snr=2.4041630560342617 and rho = 0.5
# At iter = 0 we have diff = 1.8397951983034473e-06 and overlap=5.036222979183004e-05
# At iter = 10 we have diff = 0.01186880204948151 and overlap=0.10009763310767804
# At iter = 20 we have diff = 0.0013537571929105323 and overlap=0.36116095762892964
# At iter = 30 we have diff = 2.2671246284139005e-05 and overlap=0.3866279328518722
# At iter = 40 we have diff = 9.344756790175936e-07 and overlap=0.3896999640040948
# At iter = 50 we have diff = 1.1291589345418302e-07 and overlap=0.39039707844861776
# At iter = 51 AMP converged with overlap=0.39043044368645324
# AMP iteration with snr=2.4041630560342617 and rho = 0.5
# At iter = 0 we have diff = 1.7687714917177646e-06 and overlap=-2.938624281786154e-06
# At iter = 10 we have diff = 0.0016494231609484927 and overlap=0.01774611945841173
# At iter = 20 we have diff = 0.011044938221079527 and overlap=0.3290135993666355
# At iter = 30 we have diff = 7.231142542375547e-05 and overlap=0.40728145385917364
# At iter = 40 we have diff = 1.9577114354555445e-06 and overlap=0.41396167324662636
# At iter = 50 we have diff = 1.1535650632336531e-07 and overlap=0.41519608959668836
# At iter = 51 AMP converged with overlap=0.4152433216537383
# AMP iteration with snr=2.781286672667087 and rho = 0.5
# At iter = 0 we have diff = 1.8630998022637084e-06 and overlap=-1.4884490810334866e-05
# At iter = 10 we have diff = 0.13637937521662763 and overlap=-0.3751754690076712
# At iter = 20 we have diff = 0.00013668945825941233 and overlap=-0.4908978545221174
# At iter = 30 we have diff = 1.2778654304743942e-06 and overlap=-0.4968498034090311
# At iter = 38 AMP converged with overlap=-0.497542247464539
# AMP iteration with snr=2.781286672667087 and rho = 0.5
# At iter = 0 we have diff = 1.7715033435126117e-06 and overlap=-2.348571091584769e-05
# At iter = 10 we have diff = 0.12233121967110583 and overlap=-0.35219365111802076
# At iter = 20 we have diff = 0.00014728583081599105 and overlap=-0.48498480305538444
# At iter = 30 we have diff = 7.451220711908312e-07 and overlap=-0.48957325016936304
# At iter = 37 AMP converged with overlap=-0.48994506210767635
# AMP iteration with snr=2.781286672667087 and rho = 0.5
# At iter = 0 we have diff = 1.7964376535183085e-06 and overlap=-3.742279384409409e-05
# At iter = 10 we have diff = 0.0934675361124043 and overlap=-0.25159324431974844
# At iter = 20 we have diff = 0.0006134827744254772 and overlap=-0.5008629063090855
# At iter = 30 we have diff = 5.219388727198795e-06 and overlap=-0.5094736611763341
# At iter = 40 we have diff = 3.9762725534100354e-07 and overlap=-0.5109285590878683
# At iter = 47 AMP converged with overlap=-0.5111519162449841
# AMP iteration with snr=2.781286672667087 and rho = 0.5
# At iter = 0 we have diff = 1.8819964303520607e-06 and overlap=1.279272494060992e-05
# At iter = 10 we have diff = 0.10935666350354384 and overlap=0.32684435077527785
# At iter = 20 we have diff = 0.00024751539562907634 and overlap=0.519803828098274
# At iter = 30 we have diff = 2.137910972244884e-06 and overlap=0.5268221704842964
# At iter = 40 we have diff = 8.246570929817076e-08 and overlap=0.5275926983659269
# At iter = 40 AMP converged with overlap=0.5275926983659269
# AMP iteration with snr=2.781286672667087 and rho = 0.5
# At iter = 0 we have diff = 1.841302604422931e-06 and overlap=-2.3761042008125163e-05
# At iter = 10 we have diff = 0.0911569876552401 and overlap=-0.26631612601487964
# At iter = 20 we have diff = 0.0004207626947653592 and overlap=-0.5021340925435773
# At iter = 30 we have diff = 6.863746533382289e-06 and overlap=-0.5077208418152362
# At iter = 40 we have diff = 3.614310463194954e-07 and overlap=-0.5079157794211364
# At iter = 45 AMP converged with overlap=-0.5078771872526275
# AMP iteration with snr=2.781286672667087 and rho = 0.5
# At iter = 0 we have diff = 1.8031026456985065e-06 and overlap=-9.688933965073324e-06
# At iter = 10 we have diff = 0.14894371946744334 and overlap=-0.41521657945533236
# At iter = 20 we have diff = 0.00016195301065033744 and overlap=-0.4754626692028144
# At iter = 30 we have diff = 2.0970377500275573e-06 and overlap=-0.4806512460719921
# At iter = 40 we have diff = 1.3728370206718398e-07 and overlap=-0.481413419342667
# At iter = 42 AMP converged with overlap=-0.48145489674634784
# AMP iteration with snr=2.781286672667087 and rho = 0.5
# At iter = 0 we have diff = 1.7779576080883745e-06 and overlap=-3.6210977905631025e-05
# At iter = 10 we have diff = 0.1456683319522439 and overlap=0.40825852700793147
# At iter = 20 we have diff = 7.366186456113985e-05 and overlap=0.521128516543552
# At iter = 30 we have diff = 7.085697457435409e-07 and overlap=0.5259385776500792
# At iter = 37 AMP converged with overlap=0.52639146944988
# AMP iteration with snr=2.781286672667087 and rho = 0.5
# At iter = 0 we have diff = 1.8674717099275914e-06 and overlap=2.781311865071654e-05
# At iter = 10 we have diff = 0.15334773123011539 and overlap=0.41898950031098375
# At iter = 20 we have diff = 7.335829662297679e-05 and overlap=0.506143504712606
# At iter = 30 we have diff = 1.2091521497030316e-06 and overlap=0.5108046455469428
# At iter = 40 we have diff = 8.431424309202223e-08 and overlap=0.5113507880354377
# At iter = 40 AMP converged with overlap=0.5113507880354377
# AMP iteration with snr=2.781286672667087 and rho = 0.5
# At iter = 0 we have diff = 1.7679092253928166e-06 and overlap=-0.00013348999867834893
# At iter = 10 we have diff = 0.01013796534690762 and overlap=-0.5953452832126281
# At iter = 20 we have diff = 4.520583007850491e-06 and overlap=-0.5797317805973489
# At iter = 30 we have diff = 7.502831808023926e-08 and overlap=-0.5817605671958563
# At iter = 30 AMP converged with overlap=-0.5817605671958563
# AMP iteration with snr=2.781286672667087 and rho = 0.5
# At iter = 0 we have diff = 1.7887774313925533e-06 and overlap=3.888417932426182e-06
# At iter = 10 we have diff = 0.06438462395461834 and overlap=0.04324502127095283
# At iter = 20 we have diff = 0.03828816304160343 and overlap=0.3006244516194778
# At iter = 30 we have diff = 9.169685943331699e-05 and overlap=0.5139077073719189
# At iter = 40 we have diff = 1.4443985554499274e-06 and overlap=0.5187636700557388
# At iter = 49 AMP converged with overlap=0.5192455031010796
# AMP iteration with snr=3.158410289299912 and rho = 0.5
# At iter = 0 we have diff = 1.9538163978048663e-06 and overlap=-4.106516158746972e-05
# At iter = 10 we have diff = 0.0259194065596249 and overlap=0.10321121926121371
# At iter = 20 we have diff = 0.0057320415252871725 and overlap=0.561340772414656
# At iter = 30 we have diff = 1.739641171006984e-05 and overlap=0.5802296943114434
# At iter = 40 we have diff = 6.422563144229858e-07 and overlap=0.58153559867935
# At iter = 46 AMP converged with overlap=0.5816109118821107
# AMP iteration with snr=3.158410289299912 and rho = 0.5
# At iter = 0 we have diff = 1.9101905995868213e-06 and overlap=1.9429238032579243e-05
# At iter = 10 we have diff = 0.05436969643300476 and overlap=-0.5556956833087878
# At iter = 20 we have diff = 2.247685286586188e-05 and overlap=-0.5652937266472309
# At iter = 30 we have diff = 5.089072247436517e-07 and overlap=-0.5684048147492531
# At iter = 35 AMP converged with overlap=-0.5686426684660671
# AMP iteration with snr=3.158410289299912 and rho = 0.5
# At iter = 0 we have diff = 1.8941231005695853e-06 and overlap=8.641964015428901e-05
# At iter = 10 we have diff = 0.015392841478863552 and overlap=0.528648068388392
# At iter = 20 we have diff = 1.3862845271545565e-05 and overlap=0.5130041821078186
# At iter = 30 we have diff = 8.868626071864356e-07 and overlap=0.5157441328116025
# At iter = 40 we have diff = 1.0272533567364203e-07 and overlap=0.5162219367859903
# At iter = 41 AMP converged with overlap=0.5162408391536997
# AMP iteration with snr=3.158410289299912 and rho = 0.5
# At iter = 0 we have diff = 1.940343012830274e-06 and overlap=4.192510797359836e-05
# At iter = 10 we have diff = 0.039017027833228336 and overlap=0.5738372702108536
# At iter = 20 we have diff = 1.9479143465674254e-05 and overlap=0.580926282843854
# At iter = 30 we have diff = 4.832239249917414e-07 and overlap=0.5831388587417226
# At iter = 35 AMP converged with overlap=0.5832674420498789
# AMP iteration with snr=3.158410289299912 and rho = 0.5
# At iter = 0 we have diff = 1.8859762317543899e-06 and overlap=2.2347913511566315e-06
# At iter = 10 we have diff = 0.037706693063838545 and overlap=-0.599699119828064
# At iter = 20 we have diff = 1.9797375257752593e-05 and overlap=-0.5858975494618415
# At iter = 30 we have diff = 6.310373661192726e-07 and overlap=-0.5892133516360412
# At iter = 37 AMP converged with overlap=-0.589571934170627
# AMP iteration with snr=3.158410289299912 and rho = 0.5
# At iter = 0 we have diff = 1.8796193287201707e-06 and overlap=1.858168262859096e-07
# At iter = 10 we have diff = 0.019530083901019107 and overlap=0.5806327713679751
# At iter = 20 we have diff = 1.335195643331243e-05 and overlap=0.5786122370302526
# At iter = 30 we have diff = 3.590515718601595e-07 and overlap=0.5810212994169215
# At iter = 34 AMP converged with overlap=0.5811755317567748
# AMP iteration with snr=3.158410289299912 and rho = 0.5
# At iter = 0 we have diff = 1.929501725118557e-06 and overlap=-6.387902412005767e-05
# At iter = 10 we have diff = 0.031545568206146644 and overlap=-0.535843148915949
# At iter = 20 we have diff = 2.0345533722082164e-05 and overlap=-0.5390457429098335
# At iter = 30 we have diff = 7.556088764272339e-07 and overlap=-0.5427327478866382
# At iter = 37 AMP converged with overlap=-0.543196890603744
# AMP iteration with snr=3.158410289299912 and rho = 0.5
# At iter = 0 we have diff = 1.930862996830063e-06 and overlap=0.00010578903691594785
# At iter = 10 we have diff = 0.01485626901571934 and overlap=0.5955350866041231
# At iter = 20 we have diff = 8.140249845712094e-06 and overlap=0.6018479138941498
# At iter = 30 we have diff = 2.4054511310484995e-07 and overlap=0.6037406794376483
# At iter = 33 AMP converged with overlap=0.603837921817656
# AMP iteration with snr=3.158410289299912 and rho = 0.5
# At iter = 0 we have diff = 1.8771382498659552e-06 and overlap=9.421868744680316e-05
# At iter = 10 we have diff = 0.025433081036536905 and overlap=0.6061943976884286
# At iter = 20 we have diff = 1.0882980274908367e-05 and overlap=0.5798666553729799
# At iter = 30 we have diff = 2.719489454200353e-07 and overlap=0.5824316922335757
# At iter = 34 AMP converged with overlap=0.5826101372598361
# AMP iteration with snr=3.158410289299912 and rho = 0.5
# At iter = 0 we have diff = 1.9062989852342028e-06 and overlap=-3.242874586836658e-05
# At iter = 10 we have diff = 0.05408718438997386 and overlap=0.319595750918409
# At iter = 20 we have diff = 0.0002853079600890927 and overlap=0.5533636106993713
# At iter = 30 we have diff = 2.2622912462486827e-06 and overlap=0.5591535746185993
# At iter = 40 we have diff = 7.334015670680058e-08 and overlap=0.5596474413184842
# At iter = 40 AMP converged with overlap=0.5596474413184842
# AMP iteration with snr=3.5355339059327373 and rho = 0.5
# At iter = 0 we have diff = 1.9292317279595516e-06 and overlap=1.6046103117364618e-05
# At iter = 10 we have diff = 0.02132741903596988 and overlap=0.6497710372306827
# At iter = 20 we have diff = 6.18106777551499e-06 and overlap=0.6642061270977139
# At iter = 30 we have diff = 1.510249631182193e-07 and overlap=0.6655211974363767
# At iter = 32 AMP converged with overlap=0.6655670868530729
# AMP iteration with snr=3.5355339059327373 and rho = 0.5
# At iter = 0 we have diff = 1.901943880449995e-06 and overlap=-8.810903719553229e-05
# At iter = 10 we have diff = 0.013636200468852345 and overlap=-0.6003671786216317
# At iter = 20 we have diff = 5.181127526898186e-06 and overlap=-0.6168199887161847
# At iter = 30 we have diff = 1.2234333304083312e-07 and overlap=-0.6185061146956945
# At iter = 31 AMP converged with overlap=-0.6185416960280123
# AMP iteration with snr=3.5355339059327373 and rho = 0.5
# At iter = 0 we have diff = 2.0199846501205812e-06 and overlap=-7.602588486516326e-06
# At iter = 10 we have diff = 0.039731926000971154 and overlap=-0.240834830922858
# At iter = 20 we have diff = 0.00034813907190171014 and overlap=-0.5922215006680762
# At iter = 30 we have diff = 3.263944743891766e-06 and overlap=-0.5995469816868223
# At iter = 40 we have diff = 9.477771669349517e-08 and overlap=-0.6001042649206133
# At iter = 40 AMP converged with overlap=-0.6001042649206133
# AMP iteration with snr=3.5355339059327373 and rho = 0.5
# At iter = 0 we have diff = 1.964564789749559e-06 and overlap=0.0001918877074733954
# At iter = 10 we have diff = 0.022633909741461178 and overlap=0.46792153492332034
# At iter = 20 we have diff = 1.6368496976338835e-05 and overlap=0.4732391547223016
# At iter = 30 we have diff = 2.4476475758691794e-07 and overlap=0.47550859681973223
# At iter = 34 AMP converged with overlap=0.4757399134198418
# AMP iteration with snr=3.5355339059327373 and rho = 0.5
# At iter = 0 we have diff = 1.9573682722137507e-06 and overlap=-5.7029257841507875e-06
# At iter = 10 we have diff = 0.07105650871458058 and overlap=-0.5322359076746397
# At iter = 20 we have diff = 3.097564418273475e-05 and overlap=-0.6118059551047362
# At iter = 30 we have diff = 8.00976715908699e-07 and overlap=-0.6146156769088932
# At iter = 37 AMP converged with overlap=-0.614843239597863
# AMP iteration with snr=3.5355339059327373 and rho = 0.5
# At iter = 0 we have diff = 1.9554554632277334e-06 and overlap=5.118981995397535e-05
# At iter = 10 we have diff = 0.05142384622013957 and overlap=0.6090656777232891
# At iter = 20 we have diff = 1.636064279580066e-05 and overlap=0.6457532153674861
# At iter = 30 we have diff = 3.4976761217259986e-07 and overlap=0.6484459687713168
# At iter = 34 AMP converged with overlap=0.6486452340055225
# AMP iteration with snr=3.5355339059327373 and rho = 0.5
# At iter = 0 we have diff = 2.033729894951638e-06 and overlap=6.100359547368454e-05
# At iter = 10 we have diff = 0.0218995229157297 and overlap=0.6015596699643594
# At iter = 20 we have diff = 1.3590940464212407e-05 and overlap=0.6111793658904414
# At iter = 30 we have diff = 5.989031100852876e-07 and overlap=0.6123437952736869
# At iter = 37 AMP converged with overlap=0.6123252265497399
# AMP iteration with snr=3.5355339059327373 and rho = 0.5
# At iter = 0 we have diff = 2.0075466692701777e-06 and overlap=4.675200258147548e-07
# At iter = 10 we have diff = 0.017135593177275716 and overlap=0.6257749638253829
# At iter = 20 we have diff = 7.046516924001916e-06 and overlap=0.6426069325916042
# At iter = 30 we have diff = 1.7718655397200806e-07 and overlap=0.6445304620320392
# At iter = 32 AMP converged with overlap=0.64461257834842
# AMP iteration with snr=3.5355339059327373 and rho = 0.5
# At iter = 0 we have diff = 1.8672713600413921e-06 and overlap=-1.4346472243742337e-05
# At iter = 10 we have diff = 0.0622696477189721 and overlap=-0.5047293528008614
# At iter = 20 we have diff = 5.791640088859876e-05 and overlap=-0.6039141956348294
# At iter = 30 we have diff = 1.4709995513300122e-06 and overlap=-0.6078564724205678
# At iter = 39 AMP converged with overlap=-0.6082352484414191
# AMP iteration with snr=3.5355339059327373 and rho = 0.5
# At iter = 0 we have diff = 1.9126646457135184e-06 and overlap=1.3950616749622376e-05
# At iter = 10 we have diff = 0.05927308379465615 and overlap=-0.6208914566138943
# At iter = 20 we have diff = 2.4412397742182444e-05 and overlap=-0.6619253989060649
# At iter = 30 we have diff = 5.512114761347494e-07 and overlap=-0.6644884249565823
# At iter = 35 AMP converged with overlap=-0.6646793226881355

# %% [markdown]
# ##### $\color{Purple}{\text{AMP}}$

# %%
plt.figure(figsize=(10,7))
plt.title(fr'MSE at fixed sparsity $\rho$ = {rho}',fontsize = 20)
plt.errorbar(x=coefs_amp,y=np.array(amps),yerr=errs,fmt='x',label='AMP')
plt.plot(coefs,np.array(se_inf),label='SE Informative')
plt.plot(coefs,np.array(se_inf),label='SE Uninformative')
plt.legend(fontsize = 20.5,frameon = False , ncol = 1 , loc = 'lower left')
plt.rc('xtick', labelsize=20)  
plt.rc('ytick', labelsize=20)
plt.rc('axes', labelsize=20) 
plt.xlabel(r"$\lambda \sqrt{\alpha}  $") ; plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %% [markdown]
# ### $\color{Darkred}{\text{Thresholds}}$

# %% [markdown]
# In this section we compute the *thresholds* separating different *reconstruction phases*. We exploit the definitions we give in the paper. The spinodal transitions $\{\lambda_{alg Bayes},\lambda_{dyn}\}$ are computed as critical points of the curve describing the Signal-to-Noise ratio needed to achieve a given overlap $m_u$, i.e. $\lambda(m_u)$. The IT transition $\lambda_{it}$ is found numerically by finding when the informative fixed point of the SE equations has the same free energy as the uninformative one. The algorithmical transition is always fixed at $\lambda_{alg}=1$ and defines the stability of the trivial fixed point.

# %%
rhos = [0.09,0.11,0.13,0.15] ; tol = 1e-4
alpha = 2
ms = np.linspace(10e-4,0.2,100) ; lamb_curves = [] ; lambs_it_new = [] ; lambs_dyn_new, lambs_alg_new = [],[]
for rho in rhos:
    lambs = [] ; deltaphis = []
    for val in ms:
        # Find lambda(mu)
        snr_sc = find_sol(val,alpha,rho,tol)
        lambs.append(snr_sc[0]*(np.sqrt(alpha)*rho))
        # Find free energy between trivial fixed point and magnetization mu
        var = deltaphi(val,snr_sc,alpha,rho)
        deltaphis.append(var)
        
    # Store lambda(mu) if not many rhos   
    lamb_curves.append(lambs)

    # Check when free energy changes sign to detect IT transition
    idx = np.where(np.sign(deltaphis[:-1]) != np.sign(deltaphis[1:]))[0] + 1
    it_trans = lambs[idx[len(idx)-1]]
    lambs_it_new.append(it_trans)
    if rho<0.07:
        alg_tr = 1
    else:
        peaks_alg, _ = find_peaks(np.array(lambs)) ; alg_tr = lambs[peaks_alg[0]] 
    peaks_dyn, _ = find_peaks(-np.array(lambs)) ; dyn_tr = lambs[peaks_dyn[0]] ; lambs_dyn_new.append(dyn_tr)
    lambs_alg_new.append(alg_tr)
    print(f'rho={rho} lamb_it = {it_trans} lamb_alg = {alg_tr} dyn_tr = {dyn_tr}')
# Out:
# rho=0.09 lamb_it = 0.836332324708094 lamb_alg = 1.0022876458233387 dyn_tr = 0.8184915668394201
# rho=0.11 lamb_it = 0.887985529004437 lamb_alg = 1.003798812836756 dyn_tr = 0.8734825354073305
# rho=0.13 lamb_it = 0.9300495751205604 lamb_alg = 1.0056678217350459 dyn_tr = 0.9182819006594526
# rho=0.15 lamb_it = 0.9633732005202607 lamb_alg = 1.0081093162312873 dyn_tr = 0.954784473652221

# %%
chars = ['d','c','b','a']
fig ,ax = plt.subplots(2,2,figsize=(16,13))

for i in range(len(rhos)):
    k = int(i<2) ; j = 1 - i % 2
    ax[k,j].plot(ms,lamb_curves[i])    
    ax[k,j].axhline(y=lambs_alg_new[i],linestyle = '-.',c='yellow',label=r'$\lambda_{alg-Bayes}$')
    ax[k,j].axhline(y=1,linestyle = '-',c='m',label=r'$\lambda_{alg}$')
    ax[k,j].axhline(y=lambs_it_new[i],linestyle = '--',c='c',label=r'$\lambda_{it}$')
    ax[k,j].axhline(y=lambs_dyn_new[i],linestyle = 'dotted',c='black',label=r'$\lambda_{dyn}$')
    ax[k,j].set_title(fr' $\rho =  $ {rhos[i]}',fontsize=18,loc='left',fontstyle = 'italic')
    ax[k,j].set_ylabel(r'$\lambda \sqrt{\alpha}\, $') ; ax[k,j].set_xlabel(r'$m_u$') 
    ax[k,j].set_ylim(0.8,1.05) ; ax[k,j].set_xlim(-1e-10,0.2)
    if k == 1:
        ax[k,j].legend(fontsize = 18, loc = 'upper right')
    else:
        ax[k,j].legend(fontsize = 18, loc = 'lower left') 
plt.rc('xtick', labelsize=15)  
plt.rc('ytick', labelsize=15)
plt.rc('axes', labelsize=18)
